# %%
import requests

def validate_url_exists(url: str) -> bool:
    try:
        response = requests.head(url, timeout=10) 
        # Response code 200 indicates a valid URL
        if response.status_code == 200:
            return True
        return False
    except requests.exceptions.RequestException:
        return False

# %%
def format_url_month_ts(var, month, year, 
                        base_url="https://os.zhdk.cloud.switch.ch/chelsav2/GLOBAL/monthly", 
                        version="V.2.1",
                        year_range=list(range(1979,2020))):
    """
    Generates the link to the S3 bucket where the CHELSA monthly time series is stores

    Args
        var (str): The abbreviation of the variable of interest. The options for this are "clt", "cmi", "hurs", "pet", "pr", "rsds", "sfcWind", "tas", "tasmax", "tasmin", "vpd"
        month (int): An integer representing the month of interest
        year (int): An integer representing the year of interest
        base_url (str, optional): The base of the URL to the files of interest. This should not be changed expect in the case of a version upgrade or migration of the S3 bucket
        version (str, optional): The version of CHELSA
    Returns
        file_url (str): The URL that links to the file of interest
    """
    # Available variables for the monthly timeseries
    var_opt = ["clt", "cmi", "hurs", "pet", "pr", "rsds", "sfcWind", "tas", "tasmax", "tasmin", "vpd"]
    if var not in var_opt:
        raise ValueError(f"Invalid variable name: {var}. Variable must be one of the following options {var_opt}")
    if month not in range(1,13):
        raise ValueError(f"Month invalid: {month}. Please use a number between 1 and 12")
    if year not in year_range:
        raise ValueError(f"Year invalid: {year}. Please use a number between {year_range[0]} and {year_range[-1]}")
    #Some variables start at the second month of 1979 instead of the first one
    diff_ts = ["cmi","pet","sfcWind", "tas", "tasmax", "tasmin", "vpd"]
    if var in diff_ts and month==1 and year==1979:
        raise ValueError(f"Variables [{diff_ts}] start at month 2 of year 1979. No data available for month 1")    
    if var == "rsds":
        #Naming inconsistency where year and month have switched place
        return f"{base_url}/{var}/CHELSA_{var}_{year}_{month:02d}_{version}.tif"
    elif var == "pet":
        #Naming inconsistency where '_penman' is added after variable name
        return f"{base_url}/{var}/CHELSA_{var}_penman_{month:02d}_{year}_{version}.tif"
    else:
        #Returns the formatted string, months are automatically converted to the correct string format where single digits have zero padding
        return f"{base_url}/{var}/CHELSA_{var}_{month:02d}_{year}_{version}.tif"

# %%
def format_url_month_ts(var, month, year, 
                        base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/monthly", 
                        version="V.2.1",
                        year_range=list(range(1979,2021))):
    """
    Generates the link to the S3 bucket where the CHELSA monthly time series is stores

    Args
        var (str): The abbreviation of the variable of interest. The options for this are "clt", "cmi", "hurs", "pet", "pr", "rsds", "sfcWind", "tas", "tasmax", "tasmin", "vpd"
        month (int): An integer representing the month of interest
        year (int): An integer representing the year of interest
        base_url (str, optional): The base of the URL to the files of interest. This should not be changed expect in the case of a version upgrade or migration of the S3 bucket
        version (str, optional): The version of CHELSA
    Returns
        file_url (str): The URL that links to the file of interest
    """
    # Available variables for the monthly timeseries
    var_opt = ["clt", "cmi", "hurs", "pet", "pr", "rsds", "sfcWind", "tas", "tasmax", "tasmin", "vpd"]
    if var not in var_opt:
        raise ValueError(f"Invalid variable name: {var}. Variable must be one of the following options {var_opt}")
    if month not in range(1,13):
        raise ValueError(f"Month invalid: {month}. Please use a number between 1 and 12")
    if year not in year_range:
        raise ValueError(f"Year invalid: {year}. Please use a number between {year_range[0]} and {year_range[-1]}")
    #Some variables start at the second month of 1979 instead of the first one
    diff_ts = ["cmi","pet","sfcWind", "tas", "tasmax", "tasmin", "vpd"]
    if var in diff_ts and month==1 and year==1979:
        raise ValueError(f"Variables [{diff_ts}] start at month 2 of year 1979. No data available for month 1")    
    return f"{base_url}/{var}/{year}/CHELSA_{var}_{month:02d}_{year}_{version}.tif"

# %%
for var in ["clt", "cmi", "hurs", "pet", "pr", "rsds", "sfcWind", "tas", "tasmax", "tasmin", "vpd"]:
    for year in range(1980,2020):
        for month in range(1,13):
            validate_url_exists(format_url_month_ts(var, month, year))
    print(f"{var} URLs integrity OK")
# Out:
# clt URLs integrity OK
# cmi URLs integrity OK
# hurs URLs integrity OK
# pet URLs integrity OK
# pr URLs integrity OK
# rsds URLs integrity OK
# sfcWind URLs integrity OK
# tas URLs integrity OK
# tasmax URLs integrity OK
# tasmin URLs integrity OK
# vpd URLs integrity OK

# %%
validate_url_exists(format_url_month_ts("rsds", 1, 1990))
#print("https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/monthly/rsds/1990/CHELSA_rsds_01_1990_V.2.1.tif")
# Out:
# True

# %%
format_url_month_ts("rsds", 1, 1990)=="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/monthly/rsds/1990/CHELSA_rsds_01_1990_V.2.1.tif"
# Out:
# True

# %%
format_url_month_ts("rsds", 1, 1990)=="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/monthly/rsds/1990/CHELSA_rsds_01_1990_V.2.1.tif"
# Out:
# False

# %%
https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/monthly/clt/1979/CHELSA_clt_01_1979_V.2.1.tif

# %% [markdown]
# # Drought indices

# %% [markdown]
# https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/annual/qkndvi/1982/CHELSA_qkndvi_1982_V.2.1.tif
#
# * mymd (Multiyear meteorological droughts)
# * mymd10
# * qkndvi (Kernel Normalized Difference Vegetation Index Anomaly)
#     - 1982-2018
# * spei12
#     - 12 months
#     - 1980-2018
# * spi12
#     - 12 months
#     - 1980-2018
#
# base_url = https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/annual
# -> return f"{base_url}/{var_name}/{year}/CHELSA_{var_name}_{year}_{version}.tif"

# %%
def format_chelsa_drought_url(var_name, year, 
                              month=None, version="V.2.1", base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/annual"):
    allowed_var_names = ["mymd", "mymd10", "qkndvi", "spei12", "spi12"] 
    #Variable name check
    if var_name not in allowed_var_names:
        raise ValueError(f"{var_name} invalid. Please select one of the following variables {allowed_var_names}")
    #Temporal validity check
    if (year not in list(range(1980, 2019))) and (var_name not in ["mymd", "mymd10", "spei12", "spi12"]):
        raise ValueError(f"For variables ['mymd', 'mymd10', 'spei12', 'spi12'] the year must be between [1980,2018]. Current value for year parameter: {year}")
    if (year<1982) and (var_name=="qkndvi"):
        raise ValueError(f"Index 'qkndvi' starts at year 1982. Selected year is {year}")
    if (month not in list(range(1, 13))) and (var_name in ["spei12", "spi12"]):
        raise ValueError(f"{var_name} requires a month. Given value for optional parameter 'month': {month}")
    if var_name in ["mymd", "mymd10", "qkndvi"]:
        return f"{base_url}/{var_name}/{year}/CHELSA_{var_name}_{year}_{version}.tif"
    else:
        return f"{base_url}/{var_name}/{year}/CHELSA_{var_name}_{month}_{year}_{version}.tif"

# %%
format_chelsa_drought_url("mymd", 1980)
# Out:
# 'https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/annual/mymd/1980/CHELSA_mymd_1980_V.2.1.tif'

# %%
year_lists = [list(range(1980,2019)), list(range(1980,2019)), list(range(1982,2019))]
for var, year_list in zip(["mymd", "mymd10", "qkndvi"], year_lists):
    for year in year_list:
        validate_url_exists(format_chelsa_drought_url(var, year))
    print(f"{var} URLs validated")
# Out:
# mymd URLs validated
# mymd10 URLs validated
# qkndvi URLs validated

# %%
for var in ["spei12", "spi12"]:
    for year in list(range(1980,2019)):
        for month in list(range(1,13)):
            validate_url_exists(format_chelsa_drought_url(var, year, month==month))
    print(f"{var} URLs validated")
# Out:
# spei12 URLs validated
# spi12 URLs validated

# %% [markdown]
# # Reference data

# %% [markdown]
# ## Monthly
#
# https://envicloud.wsl.ch/#/?bucket=https%3A%2F%2Fos.unil.cloud.switch.ch%2Fchelsa02%2F&prefix=chelsa%2Fglobal%2Fclimatologies%2F
#
# https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/climatologies/clt/1981-2010/CHELSA_clt_01_1981-2010_V.2.1.tif
#
# Verify whether all links stored are still valid
#
# - CHELSA_clt_01_1981-2010_V.2.1.tif
# - CHELSA_cmi_01_1981-2010_V.2.1.tif
# - CHELSA_hurs_01_1981-2010_V.2.1.tif
# - CHELSA_pet_01_1981-2010_V.2.1.tif
# - CHELSA_pr_01_1981-2010_V.2.1.tif
# - CHELSA_rsds_01_1981-2010_V.2.1.tif
# - CHELSA_sfcWind_01_1981-2010_V.2.1.tif
# - CHELSA_tas_01_1981-2010_V.2.1.tif
# - CHELSA_tasmax_01_1981-2010_V.2.1.tif
# - CHELSA_tasmin_01_1981-2010_V.2.1.tif
# - CHELSA_vpd_01_1981-2010_V.2.1.tif
#
# CHELSA_{var}\_{month}\_{ref_period}_{version}.tif

# %%
def format_url_clim_ref_monthly(var, month,
                                ref_period = "1981-2010",
                                base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/climatologies",
                                version="V.2.1"):
    """
    Generate URL's that link to the reference data tif files on a monthly basis for the reference period 1980-2010 
    """
    var_opt=["clt","cmi","hurs","pet","pr","rsds","sfcWind","tas","tasmax","tasmin", "vpd"]
    if var not in var_opt:
        raise ValueError(f"Invalid variable name: {var}. Variable must be one of the following options {var_opt}")
    if month not in range(1,13):
        raise ValueError(f"Month invalid: {month}. Please use a number between 1 and 12")
    else:
        return f"{base_url}/{var}/{ref_period}/CHELSA_{var}_{month}_{ref_period}_{version}.tif"

# %%
var_opt=["clt","cmi","hurs","pet","pr","rsds","sfcWind","tas","tasmax","tasmin", "vpd"]
for var in var_opt:
    for month in range(1,13):
        validate_url_exists(format_url_clim_ref_monthly(var, month))
    print(f"{var} URLs valid")
# Out:
# clt URLs valid
# cmi URLs valid
# hurs URLs valid
# pet URLs valid
# pr URLs valid
# rsds URLs valid
# sfcWind URLs valid
# tas URLs valid
# tasmax URLs valid
# tasmin URLs valid
# vpd URLs valid

# %% [markdown]
# ## Period

# %%
def format_url_clim_ref_period(var,
                               ref_period = "1981-2010",
                               base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/bioclim",
                               version="V.2.1"):
    """
    Generate URL's that link to the reference data tif files for the BIOCLIM+ variables for the reference period 1980-2010
    """
    var_opt = ["bio01", "bio02", "bio03", "bio04", "bio05", "bio06", "bio07", "bio08", "bio09", "bio10", 
               "bio11", "bio12", "bio13", "bio14", "bio15", "bio16", "bio17", "bio18", "bio19", "cltmax", 
               "cltmean", "cltmin", "cltrange", "cmimax", "cmimean", "cmimin", "cmirange", "fcf", "fgd", 
               "gdd0", "gdd10", "gdd5", "gddlgd0", "gddlgd10", "gddlgd5", "gdgfgd10", "gdgfgd5", "gsl", 
               "gsp", "gst", "hursmax", "hursmean", "hursmin", "hursrange", "kg0", "kg1", "kg2", "kg3", 
               "kg4", "kg5", "lgd", "ngd0", "ngd10", "ngd5", "npp", "petmax", "petmean", "petmin", "petrange",
               "rsdsmax", "rsdsmean", "rsdsmin", "rsdsrange", "scd", "sfcWindmax", "sfcWindmean", "sfcWindmin", 
               "sfcWindrange", "swb", "swe", "vpdmax", "vpdmean", "vpdmin", "vpdrange"]
    if var not in var_opt:
        raise ValueError(f"Invalid variable name: {var}. Variable must be one of the following options {var_opt}")
    else:  
        return f"{base_url}/{var}/CHELSA_{var}_{ref_period}_{version}.tif"

# %%
var_opt = ["bio01", "bio02", "bio03", "bio04", "bio05", "bio06", "bio07", "bio08", "bio09", "bio10", 
               "bio11", "bio12", "bio13", "bio14", "bio15", "bio16", "bio17", "bio18", "bio19", "cltmax", 
               "cltmean", "cltmin", "cltrange", "cmimax", "cmimean", "cmimin", "cmirange", "fcf", "fgd", 
               "gdd0", "gdd10", "gdd5", "gddlgd0", "gddlgd10", "gddlgd5", "gdgfgd10", "gdgfgd5", "gsl", 
               "gsp", "gst", "hursmax", "hursmean", "hursmin", "hursrange", "kg0", "kg1", "kg2", "kg3", 
               "kg4", "kg5", "lgd", "ngd0", "ngd10", "ngd5", "npp", "petmax", "petmean", "petmin", "petrange",
               "rsdsmax", "rsdsmean", "rsdsmin", "rsdsrange", "scd", "sfcWindmax", "sfcWindmean", "sfcWindmin", 
               "sfcWindrange", "swb", "swe", "vpdmax", "vpdmean", "vpdmin", "vpdrange"]

for var in var_opt:
    validate_url_exists(format_url_clim_ref_period(var))
    print(f"{var} reference URL exists")
# Out:
# bio01 reference URL exists
# bio02 reference URL exists
# bio03 reference URL exists
# bio04 reference URL exists
# bio05 reference URL exists
# bio06 reference URL exists
# bio07 reference URL exists
# bio08 reference URL exists
# bio09 reference URL exists
# bio10 reference URL exists
# bio11 reference URL exists
# bio12 reference URL exists
# bio13 reference URL exists
# bio14 reference URL exists
# bio15 reference URL exists
# bio16 reference URL exists
# bio17 reference URL exists
# bio18 reference URL exists
# bio19 reference URL exists
# cltmax reference URL exists
# cltmean reference URL exists
# cltmin reference URL exists
# cltrange reference URL exists
# cmimax reference URL exists
# cmimean reference URL exists
# cmimin reference URL exists
# cmirange reference URL exists
# fcf reference URL exists
# fgd reference URL exists
# gdd0 reference URL exists
# gdd10 reference URL exists
# gdd5 reference URL exists
# gddlgd0 reference URL exists
# gddlgd10 reference URL exists
# gddlgd5 reference URL exists
# gdgfgd10 reference URL exists
# gdgfgd5 reference URL exists
# gsl reference URL exists
# gsp reference URL exists
# gst reference URL exists
# hursmax reference URL exists
# hursmean reference URL exists
# hursmin reference URL exists
# hursrange reference URL exists
# kg0 reference URL exists
# kg1 reference URL exists
# kg2 reference URL exists
# kg3 reference URL exists
# kg4 reference URL exists
# kg5 reference URL exists
# lgd reference URL exists
# ngd0 reference URL exists
# ngd10 reference URL exists
# ngd5 reference URL exists
# npp reference URL exists
# petmax reference URL exists
# petmean reference URL exists
# petmin reference URL exists
# petrange reference URL exists
# rsdsmax reference URL exists
# rsdsmean reference URL exists
# rsdsmin reference URL exists
# rsdsrange reference URL exists
# scd reference URL exists
# sfcWindmax reference URL exists
# sfcWindmean reference URL exists
# sfcWindmin reference URL exists
# sfcWindrange reference URL exists
# swb reference URL exists
# swe reference URL exists
# vpdmax reference URL exists
# vpdmean reference URL exists
# vpdmin reference URL exists
# vpdrange reference URL exists

# %% [markdown]
# # Simulation data

# %% [markdown]
# ## Period

# %%
var_opt = ["bio01", "bio02", "bio03", "bio04", "bio05", "bio06", "bio07", "bio08", "bio09", "bio10", 
           "bio11", "bio12", "bio13", "bio14", "bio15", "bio16", "bio17", "bio18", "bio19", "fcf", "fgd", 
           "gdd0", "gdd10", "gdd5", "gddlgd0", "gddlgd10", "gddlgd5", "gdgfgd10", "gdgfgd5", "gsl", "gsp", 
           "gst", "kg0", "kg1", "kg2", "kg3", "kg4", "kg5", "lgd", "ngd0", "ngd10", "ngd5", "npp","scd"]

# %%
def format_url_clim_sim_period(var, year_range, model_name, scenario, 
                               base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/bioclim",
                               version="V.2.1"):
    """
    generate url that link to the files in the S3 bucket that contain the future climate projections
    """
    var_opt = ["bio01", "bio02", "bio03", "bio04", "bio05", "bio06", "bio07", "bio08", "bio09", "bio10", 
               "bio11", "bio12", "bio13", "bio14", "bio15", "bio16", "bio17", "bio18", "bio19", "fcf", "fgd", 
               "gdd0", "gdd10", "gdd5", "gddlgd0", "gddlgd10", "gddlgd5", "gdgfgd10", "gdgfgd5", "gsl", "gsp", 
               "gst", "kg0", "kg1", "kg2", "kg3", "kg4", "kg5", "lgd", "ngd0", "ngd10", "ngd5", "npp","scd"]
    if var not in var_opt:
        raise ValueError(f"Variable invalid:{var} Variable must be one the following options {var_opt}")
    model_names = ['GFDL-ESM4','IPSL-CM6A-LR','MPI-ESM1-2-HR','MRI-ESM2-0','UKESM1-0-LL','gfdl-esm4','ipsl-cm6a-lr','mpi-esm1-2-hr','mri-esm2-0','ukesm1-0-ll']
    if model_name not in model_names or model_name.upper() not in model_names:
        raise ValueError(f"Modelname invalid: {model_name} Please use on of the following model names {model_names}")
    scenarios = ["ssp126","ssp370","ssp585"]
    if scenario not in scenarios:
        raise ValueError(f"Ensemble member invalid: {scenario} Please use one of the following ensemble members {scenarios}")
    year_ranges = ["2011-2040","2041-2070","2071-2100"]
    if year_range not in year_ranges:
        raise ValueError(f"Year range invalid: {year_range} Please use on of the following year ranges {year_ranges}")
    return f"{base_url}/{var}/{year_range}/{model_name.upper()}/{scenario.lower()}/CHELSA_{model_name.lower()}_{scenario.lower()}_{var}_{year_range}_{version}.tif"

# %%
var_opt = ["bio01", "bio02", "bio03", "bio04", "bio05", "bio06", "bio07", "bio08", "bio09", "bio10", 
           "bio11", "bio12", "bio13", "bio14", "bio15", "bio16", "bio17", "bio18", "bio19", "fcf", "fgd", 
           "gdd0", "gdd10", "gdd5", "gddlgd0", "gddlgd10", "gddlgd5", "gdgfgd10", "gdgfgd5", "gsl", "gsp", 
           "gst", "kg0", "kg1", "kg2", "kg3", "kg4", "kg5", "lgd", "ngd0", "ngd10", "ngd5", "npp","scd"]
model_names = ['GFDL-ESM4','IPSL-CM6A-LR','MPI-ESM1-2-HR','MRI-ESM2-0','UKESM1-0-LL']
scenarios = ["ssp126","ssp370","ssp585"]
year_ranges = ["2011-2040","2041-2070","2071-2100"]

for var in var_opt:
    print(f"------Testing {var}------")
    for model_name in model_names:
        print(f"\t Testing model: {model_name}")
        for scenario in scenarios:
            print(f"\t\t Testing scenario {scenario}")
            for year_range in year_ranges:
                validate_url_exists(format_url_clim_sim_period(var, year_range, model_name, scenario))
                print(f"\t\t\t year range {year_range}: OK")
    print("\n")
# Out:
# ------Testing bio01------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio02------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio03------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio04------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio05------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio06------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio07------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio08------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio09------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio10------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio11------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio12------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio13------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio14------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio15------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio16------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio17------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio18------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing bio19------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing fcf------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing fgd------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing gdd0------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing gdd10------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing gdd5------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing gddlgd0------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing gddlgd10------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# ...
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing kg4------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing kg5------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing lgd------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing ngd0------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing ngd10------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing ngd5------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing npp------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
#
#
# ------Testing scd------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK

# %% [markdown]
# ## Monthly

# %%
def format_url_clim_sim_month(var, year_range, month, model_name, scenario, 
                              base_url="https://os.unil.cloud.switch.ch/chelsa02/chelsa/global/climatologies",
                              version="V.2.1"):
    """
    generate url that link to the files in the S3 bucket that contain the future climate projections for a specific month

    Currently the naming convention for the file is inconsistent with the other files and might get adjusted in the future
    """
    var_opt=["pr", "tas", "tasmax", "tasmin"]
    if var not in var_opt:
        raise ValueError(f"Variable invalid:{var} Variable must be one the following options {var_opt}")
    model_names = ['GFDL-ESM4','IPSL-CM6A-LR','MPI-ESM1-2-HR','MRI-ESM2-0','UKESM1-0-LL','gfdl-esm4','ipsl-cm6a-lr','mpi-esm1-2-hr','mri-esm2-0','ukesm1-0-ll']
    if model_name not in model_names or model_name.upper() not in model_names:
        raise ValueError(f"Modelname invalid: {model_name} Please use on of the following model names {model_names}")
    scenarios = ["ssp126","ssp370","ssp585"]
    if scenario not in scenarios:
        raise ValueError(f"Ensemble member invalid: {scenario} Please use one of the following ensemble members {scenarios}")
    year_ranges = ["2011-2040","2041-2070","2071-2100"]
    if year_range not in year_ranges:
        raise ValueError(f"Year range invalid: {year_range} Please use on of the following year ranges {year_ranges}")
    return (f"{base_url}/{var}/{year_range}/{model_name.upper()}/{scenario.lower()}/CHELSA_{model_name.lower()}_r1i1p1f1_w5e5_{scenario.lower()}_{var.lower()}_{month:02d}_{year_range}_{version}.tif")

# %%
var_opt=["pr", "tas", "tasmax", "tasmin"]

for var in var_opt:
    print(f"------Testing {var}------")
    for model_name in model_names:
        print(f"\t Testing model: {model_name}")
        for scenario in scenarios:
            print(f"\t\t Testing scenario {scenario}")
            for year_range in year_ranges:
                for month in range(1,13):
                    validate_url_exists(format_url_clim_sim_month(var, year_range, month, model_name, scenario))
                print(f"\t\t\t year range {year_range}: OK")
# Out:
# ------Testing pr------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# ------Testing tas------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# ------Testing tasmax------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# ------Testing tasmin------
# 	 Testing model: GFDL-ESM4
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: IPSL-CM6A-LR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MPI-ESM1-2-HR
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: MRI-ESM2-0
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 	 Testing model: UKESM1-0-LL
# 		 Testing scenario ssp126
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp370
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
# 		 Testing scenario ssp585
# 			 year range 2011-2040: OK
# 			 year range 2041-2070: OK
# 			 year range 2071-2100: OK
