# %%
import openeo
# import ProcessBuilder functions
from openeo.processes import ProcessBuilder
import rasterio
import numpy as np
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
import geopandas as gpd

# %% [markdown]
# # Establish connection

# %%
# Establish a connection to openeo
connection = openeo.connect("openeofed.dataspace.copernicus.eu")
connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeofed.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %% [markdown]
# # Read Belgium Shapefile

# %%
beShape = gpd.read_file("../../data/Belgium_shapefile/be_1km.shp")
beShape.plot()
# Out:
# <Axes: >

# %%
beShape
# Out:
#             CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0      1kmE3768N3188    3768000    3188000
# 1      1kmE3768N3189    3768000    3189000
# 2      1kmE3768N3190    3768000    3190000
# 3      1kmE3769N3182    3769000    3182000
# 4      1kmE3769N3183    3769000    3183000
# ...              ...        ...        ...
# 51721  1kmE4079N3032    4079000    3032000
# 51722  1kmE4079N3033    4079000    3033000
# 51723  1kmE4079N3034    4079000    3034000
# 51724  1kmE4079N3035    4079000    3035000
# 51725  1kmE4079N3036    4079000    3036000
#
#                                                 geometry
# 0      POLYGON ((3768000 3188000, 3768000 3189000, 37...
# 1      POLYGON ((3768000 3189000, 3768000 3190000, 37...
# 2      POLYGON ((3768000 3190000, 3768000 3191000, 37...
# 3      POLYGON ((3769000 3182000, 3769000 3183000, 37...
# 4      POLYGON ((3769000 3183000, 3769000 3184000, 37...
# ...                                                  ...
# 51721  POLYGON ((4079000 3032000, 4079000 3033000, 40...
# 51722  POLYGON ((4079000 3033000, 4079000 3034000, 40...
# 51723  POLYGON ((4079000 3034000, 4079000 3035000, 40...
# 51724  POLYGON ((4079000 3035000, 4079000 3036000, 40...
# 51725  POLYGON ((4079000 3036000, 4079000 3037000, 40...
#
# [51726 rows x 4 columns]

# %% [markdown]
# The geometry is currently in a reference system that is not accepted by openeo. As such we are required to reproject the dataframe to the EPSG:4326 reference system

# %%
beShape=beShape.to_crs("EPSG:4326")
beShape
# Out:
#             CELLCODE  EOFORIGIN  NOFORIGIN  \
# 0      1kmE3768N3188    3768000    3188000
# 1      1kmE3768N3189    3768000    3189000
# 2      1kmE3768N3190    3768000    3190000
# 3      1kmE3769N3182    3769000    3182000
# 4      1kmE3769N3183    3769000    3183000
# ...              ...        ...        ...
# 51721  1kmE4079N3032    4079000    3032000
# 51722  1kmE4079N3033    4079000    3033000
# 51723  1kmE4079N3034    4079000    3034000
# 51724  1kmE4079N3035    4079000    3035000
# 51725  1kmE4079N3036    4079000    3036000
#
#                                                 geometry
# 0      POLYGON ((2.01272 51.52997, 2.01115 51.5389, 2...
# 1      POLYGON ((2.01115 51.5389, 2.00957 51.54782, 2...
# 2      POLYGON ((2.00957 51.54782, 2.008 51.55675, 2....
# 3      POLYGON ((2.03646 51.47739, 2.03489 51.48632, ...
# 4      POLYGON ((2.03489 51.48632, 2.03333 51.49525, ...
# ...                                                  ...
# 51721  POLYGON ((6.59875 50.34952, 6.59811 50.3585, 6...
# 51722  POLYGON ((6.59811 50.3585, 6.59746 50.36748, 6...
# 51723  POLYGON ((6.59746 50.36748, 6.59682 50.37645, ...
# 51724  POLYGON ((6.59682 50.37645, 6.59617 50.38543, ...
# 51725  POLYGON ((6.59617 50.38543, 6.59552 50.39441, ...
#
# [51726 rows x 4 columns]

# %% [markdown]
# The shapefile represents a grid of evenly sampled points within the boundary. In order to extract the border we must merge the cells contained in the shape file using the unary union operation. Extracting the boundary of this polygon can then be achieved easilty using the .boundary method.

# %%
merged_geometry = beShape.geometry.unary_union
merged_geometry.boundary
# Out:
# C:\Users\niels\AppData\Local\Temp\ipykernel_29024\2354760973.py:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   merged_geometry = beShape.geometry.unary_union
# <LINESTRING (2.159 51.269, 2.158 51.278, 2.144 51.277, 2.142 51.286, 2.14 51...>

# %% [markdown]
# In order to be useful in openeo we must convert this into a geoJSON object which is possible through the geo_interface method. Additional simplification of the geometry's border can be achieved using the simplify mmethod

# %%
boundary_geojson = merged_geometry.boundary.__geo_interface__

# %%
len(boundary_geojson["coordinates"])
# Out:
# 1359

# %%
simplified_boundary = merged_geometry.boundary.simplify(tolerance=.001)
simplified_boundary
# Out:
# <LINESTRING (2.159 51.269, 2.158 51.278, 2.144 51.277, 2.136 51.322, 2.122 5...>

# %%
simplifiedGeoJson = simplified_boundary.__geo_interface__

# %% [markdown]
# # Sampling the Belgium administrative border

# %%
bounds = simplified_boundary.bounds  # Returns (minx, miny, maxx, maxy)
west, south, east, north = bounds
spatialExtent = {"west": west, "south": south, "east": east, "north": north}
spatialExtent
# Out:
# {'west': 2.0080004194663563,
#  'south': 49.35404314487912,
#  'east': 6.617920977701399,
#  'north': 52.010171535783996}

# %%
datacubeBE = connection.load_collection( #Access the different available collections
    "SENTINEL2_L2A", #Specify the collection name
    spatial_extent=spatialExtent, #Define a spatial window
    temporal_extent = ["2021-06-01", "2021-06-01"], # Define a temporal window
    bands=["B04","B03", "B02","B05", "B08", "B11"] # Define which measured bands are required. 
)

# %%
datacubeBE = datacubeBE.filter_spatial(geometries=boundary_geojson).resample_spatial(100)

# %%
datacubeBE
# Out:
#     <script>
#     if (!window.customElements || !window.customElements.get('openeo-model-builder')) {
#         var el = document.createElement('script');
#         el.src = "https://cdn.jsdelivr.net/npm/@openeo/vue-components@2/assets/openeo.min.js";
#         document.head.appendChild(el);
#
#         var font = document.createElement('font');
#         font.as = "font";
#         font.type = "font/woff2";
#         font.crossOrigin = true;
#         font.href = "https://use.fontawesome.com/releases/v5.13.0/webfonts/fa-solid-900.woff2"
#         document.head.appendChild(font);
#     }
#     </script>
#     <openeo-model-builder>
534230654556], [2.096293356407525, 51.71631543138878], [2.0947281431931053, 51.725242269200216], [2.109128984002651, 51.7262138505777], [2.107565805555663, 51.735140865507354], [2.121970010716294, 51.73611090264082], [2.120408869571467, 51.74503809455453], [2.13481644025815, 51.74600658666512], [2.133257338952865, 51.75493395542831], [2.147668276340222, 51.755900901736645], [2.146111217414508, 51.76482844721425], [2.160525522676811, 51.76579384694043], [2.158970508673366, 51.77472156899698], [2.1733881829845463, 51.7756854213605], [2.17183521644872, 51.7846133198601], [2.186256260982344, 51.78557562407995], [2.1847053444621554, 51.79450369888626], [2.19912976039145, 51.795464454180845], [2.1975808964375747, 51.80439270 ...

# %%
res = datacubeBE.save_result(format = "GTIFF")

# send job to back-end
job = res.create_job(title = "BEsample")
job.start_and_wait()
job.get_results().download_files("BESample")
# Out:
# 0:00:00 Job 'cdse-j-25042314125543d0a2c058c150911214': send 'start'
# 0:00:15 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:00:21 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:00:27 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:00:35 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:00:46 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:00:58 Job 'cdse-j-25042314125543d0a2c058c150911214': queued (progress 0%)
# 0:01:14 Job 'cdse-j-25042314125543d0a2c058c150911214': error (progress N/A)
# Your batch job 'cdse-j-25042314125543d0a2c058c150911214' failed. Error logs:
# [{'id': '[1745417611220, 465386]', 'time': '2025-04-23T14:13:31.220Z', 'level': 'error', 'message': "OpenEO batch job failed: java.lang.ClassCastException: class org.locationtech.jts.geom.LineString cannot be cast to class org.locationtech.jts.geom.Polygon (org.locationtech.jts.geom.LineString and org.locationtech.jts.geom.Polygon are in unnamed module of loader 'app')"}]
# Full logs can be inspected in an openEO (web) editor or with `connection.job('cdse-j-25042314125543d0a2c058c150911214').logs()`.
# ---------------------------------------------------------------------------
# JobFailedException                        Traceback (most recent call last)
# Cell In[74], line 5
#       3 # send job to back-end
#       4 job = res.create_job(title = "BEsample")
# ----> 5 job.start_and_wait()
#       6 job.get_results().download_files("BESample")
#
# File ~\Anaconda3\envs\BmC\Lib\site-packages\openeo\rest\job.py:324, in BatchJob.start_and_wait(self, print, max_poll_interval, connection_retry_interval, soft_error_max)
#     320     print(self.logs(level=logging.ERROR))
#     321     print(
#     322         f"Full logs can be inspected in an openEO (web) editor or with `connection.job({self.job_id!r}).logs()`."
#     323     )
# --> 324     raise JobFailedException(
#     325         f"Batch job {self.job_id!r} didn't finish successfully. Status: {status} (after {elapsed()}).",
#     326         job=self,
#     327     )
#     329 return self
#
# JobFailedException: Batch job 'cdse-j-25042314125543d0a2c058c150911214' didn't finish successfully. Status: error (after 0:01:14).
