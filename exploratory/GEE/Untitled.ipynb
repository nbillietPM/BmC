# %%
import matplotlib.pyplot as plt
from soilgrids import SoilGrids

# get data from SoilGrids
soil_grids = SoilGrids()
data = soil_grids.get_coverage_data(
    service_id="phh2o",
    coverage_id="phh2o_0-5cm_mean",
    west=-1784000,
    south=1356000,
    east=-1140000,
    north=1863000,
    crs="urn:ogc:def:crs:EPSG::152160",
    output="test.tif",
)

# show metadata
for key, value in soil_grids.metadata.items():
    print(f"{key}: {value}")


# plot data
data.plot(figsize=(9, 5), vmin=0)
plt.title("Mean pH between 0 and 5 cm soil depth in Senegal")
# Out:
# variable_name: Soil pH in H2O
# variable_units: pH*10
# service_url: https://maps.isric.org/mapserv?map=/map/phh2o.map
# service_id: phh2o
# coverage_id: phh2o_0-5cm_mean
# crs: urn:ogc:def:crs:EPSG::152160
# bounding_box: (-1784000, 1356000, -1140000, 1863000)
# grid_res: [250, 250]
# Text(0.5, 1.0, 'Mean pH between 0 and 5 cm soil depth in Senegal')

# %%
data.dims
# Out:
# ('band', 'y', 'x')

# %%
data["x"]
# Out:
# <xarray.DataArray 'x' (x: 2576)> Size: 21kB
# array([-1783875., -1783625., -1783375., ..., -1140625., -1140375., -1140125.],
#       shape=(2576,))
# Coordinates:
#   * x            (x) float64 21kB -1.784e+06 -1.784e+06 ... -1.14e+06 -1.14e+06
#     spatial_ref  int64 8B 0

# %%
data["y"]
# Out:
# <xarray.DataArray 'y' (y: 2028)> Size: 16kB
# array([1862875., 1862625., 1862375., ..., 1356625., 1356375., 1356125.],
#       shape=(2028,))
# Coordinates:
#   * y            (y) float64 16kB 1.863e+06 1.863e+06 ... 1.356e+06 1.356e+06
#     spatial_ref  int64 8B 0

# %%
data["band"]
# Out:
# <xarray.DataArray 'band' (band: 1)> Size: 8B
# array([1])
# Coordinates:
#   * band         (band) int64 8B 1
#     spatial_ref  int64 8B 0

# %%
data.shape
# Out:
# (1, 2028, 2576)
