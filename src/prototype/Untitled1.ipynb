# %%
import pygbif
import os
import pandas as pd
import itertools

# %% [markdown]
# # Lookup taxon names

# %% [markdown]
# Lookup a single scientific names information

# %%
testName = "Arabis soyeri"

pygbif.species.name_backbone(name=testName)
# Out:
# {'usageKey': 5374901,
#  'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#  'canonicalName': 'Arabis soyeri',
#  'rank': 'SPECIES',
#  'status': 'ACCEPTED',
#  'confidence': 99,
#  'matchType': 'EXACT',
#  'kingdom': 'Plantae',
#  'phylum': 'Tracheophyta',
#  'order': 'Brassicales',
#  'family': 'Brassicaceae',
#  'genus': 'Arabis',
#  'species': 'Arabis soyeri',
#  'kingdomKey': 6,
#  'phylumKey': 7707728,
#  'classKey': 220,
#  'orderKey': 7225535,
#  'familyKey': 3112,
#  'genusKey': 5374837,
#  'speciesKey': 5374901,
#  'synonym': False,
#  'class': 'Magnoliopsida'}

# %% [markdown]
# Look up a list of names

# %%
testNames = "Arabis soyeri, Bryum pseudotriquetrum, Carex appropinquata, Catoscopium nigritum, Cochlearia pyrenaica, Cratoneuron commutatum, Cratoneuron filicinum, Drepanocladus vernicosus, Epilobium davuricum, Eucladium verticillatum, Juncus triglumis, Philonotis calcarea, Saxifraga aizoides, Scorpidium revolvens"
namesList = testNames.split(",")
print(namesList)
# Out:
# ['Arabis soyeri', ' Bryum pseudotriquetrum', ' Carex appropinquata', ' Catoscopium nigritum', ' Cochlearia pyrenaica', ' Cratoneuron commutatum', ' Cratoneuron filicinum', ' Drepanocladus vernicosus', ' Epilobium davuricum', ' Eucladium verticillatum', ' Juncus triglumis', ' Philonotis calcarea', ' Saxifraga aizoides', ' Scorpidium revolvens']

# %%
taxonInfo = list(map(lambda x: pygbif.species.name_backbone(name=x), namesList))

# %%
taxonInfo
# Out:
# [{'usageKey': 5374901,
#   'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#   'canonicalName': 'Arabis soyeri',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 99,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Brassicales',
#   'family': 'Brassicaceae',
#   'genus': 'Arabis',
#   'species': 'Arabis soyeri',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 7225535,
#   'familyKey': 3112,
#   'genusKey': 5374837,
#   'speciesKey': 5374901,
#   'synonym': False,
#   'class': 'Magnoliopsida'},
#  {'usageKey': 2676867,
#   'acceptedUsageKey': 7459211,
#   'scientificName': 'Bryum pseudotriquetrum (Hedw.) G.Gaertn., B.Mey. & Scherb.',
#   'canonicalName': 'Bryum pseudotriquetrum',
#   'rank': 'SPECIES',
#   'status': 'SYNONYM',
#   'confidence': 97,
#   'note': '3 synonym homonyms',
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Bryales',
#   'family': 'Bryaceae',
#   'genus': 'Ptychostomum',
#   'species': 'Ptychostomum pseudotriquetrum',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 1333,
#   'familyKey': 8736,
#   'genusKey': 3230073,
#   'speciesKey': 7459211,
#   'synonym': True,
#   'class': 'Bryopsida'},
#  {'usageKey': 2727917,
#   'scientificName': 'Carex appropinquata Schumach.',
#   'canonicalName': 'Carex appropinquata',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 99,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Poales',
#   'family': 'Cyperaceae',
#   'genus': 'Carex',
#   'species': 'Carex appropinquata',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 196,
#   'orderKey': 1369,
#   'familyKey': 7708,
#   'genusKey': 2721893,
#   'speciesKey': 2727917,
#   'synonym': False,
#   'class': 'Liliopsida'},
#  {'usageKey': 2676491,
#   'scientificName': 'Catoscopium nigritum (Hedw.) Brid.',
#   'canonicalName': 'Catoscopium nigritum',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 99,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Catoscopiales',
#   'family': 'Catoscopiaceae',
#   'genus': 'Catoscopium',
#   'species': 'Catoscopium nigritum',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 12237270,
#   'familyKey': 8740,
#   'genusKey': 2676490,
#   'speciesKey': 2676491,
#   'synonym': False,
#   'class': 'Bryopsida'},
#  {'usageKey': 5373255,
#   'scientificName': 'Cochlearia pyrenaica DC.',
#   'canonicalName': 'Cochlearia pyrenaica',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 99,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Brassicales',
#   'family': 'Brassicaceae',
#   'genus': 'Cochlearia',
#   'species': 'Cochlearia pyrenaica',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 7225535,
#   'familyKey': 3112,
#   'genusKey': 3040481,
#   'speciesKey': 5373255,
#   'synonym': False,
#   'class': 'Magnoliopsida'},
#  {'usageKey': 4279712,
#   'acceptedUsageKey': 2681729,
#   'scientificName': 'Cratoneuron commutatum (Hedw.) G.Roth',
#   'canonicalName': 'Cratoneuron commutatum',
#   'rank': 'SPECIES',
#   'status': 'SYNONYM',
#   'confidence': 98,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Hypnales',
#   'family': 'Amblystegiaceae',
#   'genus': 'Palustriella',
#   'species': 'Palustriella commutata',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 617,
#   'familyKey': 4650,
#   'genusKey': 2681727,
#   'speciesKey': 2681729,
#   'synonym': True,
#   'class': 'Bryopsida'},
#  {'usageKey': 2673131,
#   'scientificName': 'Cratoneuron filicinum (Hedw.) Spruce',
#   'canonicalName': 'Cratoneuron filicinum',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 97,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Hypnales',
#   'family': 'Amblystegiaceae',
#   'genus': 'Cratoneuron',
#   'species': 'Cratoneuron filicinum',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 617,
#   'familyKey': 4650,
#   'genusKey': 2673130,
#   'speciesKey': 2673131,
#   'synonym': False,
#   'class': 'Bryopsida'},
#  {'usageKey': 5710895,
#   'acceptedUsageKey': 2681714,
#   'scientificName': 'Drepanocladus vernicosus (Mitt.) Warnst.',
#   'canonicalName': 'Drepanocladus vernicosus',
#   'rank': 'SPECIES',
#   'status': 'SYNONYM',
#   'confidence': 98,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Hypnales',
#   'family': 'Scorpidiaceae',
#   'genus': 'Hamatocaulis',
#   'species': 'Hamatocaulis vernicosus',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 617,
#   'familyKey': 4894159,
#   'genusKey': 2681713,
#   'speciesKey': 2681714,
#   'synonym': True,
#   'class': 'Bryopsida'},
#  {'usageKey': 3189103,
#   'scientificName': 'Epilobium davuricum Fisch. ex Hornem.',
#   'canonicalName': 'Epilobium davuricum',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 98,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Myrtales',
#   'family': 'Onagraceae',
#   'genus': 'Epilobium',
#   'species': 'Epilobium davuricum',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 690,
#   'familyKey': 2430,
#   'genusKey': 3189067,
#   'speciesKey': 3189103,
#   'synonym': False,
#   'class': 'Magnoliopsida'},
#  {'usageKey': 2671130,
#   'scientificName': 'Eucladium verticillatum (With.) Bruch & Schimp.',
#   'canonicalName': 'Eucladium verticillatum',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 97,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Pottiales',
#   'family': 'Pottiaceae',
#   'genus': 'Eucladium',
#   'species': 'Eucladium verticillatum',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 621,
#   'familyKey': 4671,
#   'genusKey': 2671129,
#   'speciesKey': 2671130,
#   'synonym': False,
#   'class': 'Bryopsida'},
#  {'usageKey': 2701939,
#   'scientificName': 'Juncus triglumis L.',
#   'canonicalName': 'Juncus triglumis',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 97,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Poales',
#   'family': 'Juncaceae',
#   'genus': 'Juncus',
#   'species': 'Juncus triglumis',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 196,
#   'orderKey': 1369,
#   'familyKey': 5353,
#   'genusKey': 2701072,
#   'speciesKey': 2701939,
#   'synonym': False,
#   'class': 'Liliopsida'},
#  {'usageKey': 2676091,
#   'scientificName': 'Philonotis calcarea (Bruch & Schimp.) Schimp.',
#   'canonicalName': 'Philonotis calcarea',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 99,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Bartramiales',
#   'family': 'Bartramiaceae',
#   'genus': 'Philonotis',
#   'species': 'Philonotis calcarea',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 12239937,
#   'familyKey': 8737,
#   'genusKey': 2676069,
#   'speciesKey': 2676091,
#   'synonym': False,
#   'class': 'Bryopsida'},
#  {'usageKey': 8165236,
#   'scientificName': 'Saxifraga aizoides L.',
#   'canonicalName': 'Saxifraga aizoides',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 97,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Tracheophyta',
#   'order': 'Saxifragales',
#   'family': 'Saxifragaceae',
#   'genus': 'Saxifraga',
#   'species': 'Saxifraga aizoides',
#   'kingdomKey': 6,
#   'phylumKey': 7707728,
#   'classKey': 220,
#   'orderKey': 7219248,
#   'familyKey': 2402,
#   'genusKey': 2987833,
#   'speciesKey': 8165236,
#   'synonym': False,
#   'class': 'Magnoliopsida'},
#  {'usageKey': 2681640,
#   'scientificName': 'Scorpidium revolvens (Sw.) Rubers',
#   'canonicalName': 'Scorpidium revolvens',
#   'rank': 'SPECIES',
#   'status': 'ACCEPTED',
#   'confidence': 97,
#   'matchType': 'EXACT',
#   'kingdom': 'Plantae',
#   'phylum': 'Bryophyta',
#   'order': 'Hypnales',
#   'family': 'Scorpidiaceae',
#   'genus': 'Scorpidium',
#   'species': 'Scorpidium revolvens',
#   'kingdomKey': 6,
#   'phylumKey': 35,
#   'classKey': 327,
#   'orderKey': 617,
#   'familyKey': 4894159,
#   'genusKey': 2681638,
#   'speciesKey': 2681640,
#   'synonym': False,
#   'class': 'Bryopsida'}]

# %% [markdown]
# Convert taxoninfo into dataframe

# %%
import pandas as pd
# Out:
# INFO:Note: NumExpr detected 22 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:NumExpr defaulting to 8 threads.

# %%
pd.DataFrame(taxonInfo)
# Out:
#     usageKey                                     scientificName  \
# 0    5374901                      Arabis soyeri Reut. & A.Huet.
# 1    2676867  Bryum pseudotriquetrum (Hedw.) G.Gaertn., B.Me...
# 2    2727917                      Carex appropinquata Schumach.
# 3    2676491                 Catoscopium nigritum (Hedw.) Brid.
# 4    5373255                           Cochlearia pyrenaica DC.
# 5    4279712              Cratoneuron commutatum (Hedw.) G.Roth
# 6    2673131               Cratoneuron filicinum (Hedw.) Spruce
# 7    5710895           Drepanocladus vernicosus (Mitt.) Warnst.
# 8    3189103              Epilobium davuricum Fisch. ex Hornem.
# 9    2671130    Eucladium verticillatum (With.) Bruch & Schimp.
# 10   2701939                                Juncus triglumis L.
# 11   2676091      Philonotis calcarea (Bruch & Schimp.) Schimp.
# 12   8165236                              Saxifraga aizoides L.
# 13   2681640                  Scorpidium revolvens (Sw.) Rubers
#
#                canonicalName     rank    status  confidence matchType  \
# 0              Arabis soyeri  SPECIES  ACCEPTED          99     EXACT
# 1     Bryum pseudotriquetrum  SPECIES   SYNONYM          97     EXACT
# 2        Carex appropinquata  SPECIES  ACCEPTED          99     EXACT
# 3       Catoscopium nigritum  SPECIES  ACCEPTED          99     EXACT
# 4       Cochlearia pyrenaica  SPECIES  ACCEPTED          99     EXACT
# 5     Cratoneuron commutatum  SPECIES   SYNONYM          98     EXACT
# 6      Cratoneuron filicinum  SPECIES  ACCEPTED          97     EXACT
# 7   Drepanocladus vernicosus  SPECIES   SYNONYM          98     EXACT
# 8        Epilobium davuricum  SPECIES  ACCEPTED          98     EXACT
# 9    Eucladium verticillatum  SPECIES  ACCEPTED          97     EXACT
# 10          Juncus triglumis  SPECIES  ACCEPTED          97     EXACT
# 11       Philonotis calcarea  SPECIES  ACCEPTED          99     EXACT
# 12        Saxifraga aizoides  SPECIES  ACCEPTED          97     EXACT
# 13      Scorpidium revolvens  SPECIES  ACCEPTED          97     EXACT
#
#     kingdom        phylum          order  ... phylumKey classKey  orderKey  \
# 0   Plantae  Tracheophyta    Brassicales  ...   7707728      220   7225535
# 1   Plantae     Bryophyta        Bryales  ...        35      327      1333
# 2   Plantae  Tracheophyta         Poales  ...   7707728      196      1369
# 3   Plantae     Bryophyta  Catoscopiales  ...        35      327  12237270
# 4   Plantae  Tracheophyta    Brassicales  ...   7707728      220   7225535
# 5   Plantae     Bryophyta       Hypnales  ...        35      327       617
# 6   Plantae     Bryophyta       Hypnales  ...        35      327       617
# 7   Plantae     Bryophyta       Hypnales  ...        35      327       617
# 8   Plantae  Tracheophyta       Myrtales  ...   7707728      220       690
# 9   Plantae     Bryophyta      Pottiales  ...        35      327       621
# 10  Plantae  Tracheophyta         Poales  ...   7707728      196      1369
# 11  Plantae     Bryophyta   Bartramiales  ...        35      327  12239937
# 12  Plantae  Tracheophyta   Saxifragales  ...   7707728      220   7219248
# 13  Plantae     Bryophyta       Hypnales  ...        35      327       617
#
#     familyKey  genusKey  speciesKey  synonym          class  acceptedUsageKey  \
# 0        3112   5374837     5374901    False  Magnoliopsida               NaN
# 1        8736   3230073     7459211     True      Bryopsida         7459211.0
# 2        7708   2721893     2727917    False     Liliopsida               NaN
# 3        8740   2676490     2676491    False      Bryopsida               NaN
# 4        3112   3040481     5373255    False  Magnoliopsida               NaN
# 5        4650   2681727     2681729     True      Bryopsida         2681729.0
# 6        4650   2673130     2673131    False      Bryopsida               NaN
# 7     4894159   2681713     2681714     True      Bryopsida         2681714.0
# 8        2430   3189067     3189103    False  Magnoliopsida               NaN
# 9        4671   2671129     2671130    False      Bryopsida               NaN
# 10       5353   2701072     2701939    False     Liliopsida               NaN
# 11       8737   2676069     2676091    False      Bryopsida               NaN
# 12       2402   2987833     8165236    False  Magnoliopsida               NaN
# 13    4894159   2681638     2681640    False      Bryopsida               NaN
#
#                   note
# 0                  NaN
# 1   3 synonym homonyms
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
#
# [14 rows x 24 columns]

# %%
pygbif.occurrences.search(taxonKey=5374901)
# Out:
# {'offset': 0,
#  'limit': 300,
#  'endOfRecords': False,
#  'count': 7562,
#  'results': [{'key': 5108383907,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T02:16:59.023+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480780930',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:31:33-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480780930',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480780930/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480780962',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:31:27-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480780962',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480780962/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480781013',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:30:53-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480781013',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781013/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-03-29T16:22:41',
#    'decimalLatitude': 47.523392,
#    'decimalLongitude': 13.442686,
#    'coordinateUncertaintyInMeters': 5.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Salzburg',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.1_2', 'name': 'Hallein'},
#     'level3': {'gid': 'AUT.5.1.3_2', 'name': 'Annaberg-Lungötz'}},
#    'year': 2025,
#    'month': 3,
#    'day': 28,
#    'eventDate': '2025-03-28T16:31',
#    'startDayOfYear': 87,
#    'endDayOfYear': 87,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-04-14T23:36:39.000+00:00',
#    'lastInterpreted': '2025-06-07T02:16:59.023+00:00',
#    'references': 'https://www.inaturalist.org/observations/267529877',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '267529877'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480781013',
#      'created': '2025-03-28T23:30:53.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781013/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480780962',
#      'created': '2025-03-28T23:31:27.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480780962/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480780930',
#      'created': '2025-03-28T23:31:33.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480780930/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Roland Kaiser',
#    'identifiedBy': 'Roland Kaiser',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-2487-9289'}],
#    'identifiedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-2487-9289'}],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'NORTH_AMERICA',
#    'rightsHolder': 'Roland Kaiser',
#    'identifier': '267529877',
#    'http://unknown.org/nick': 'roland_kaiser',
#    'verbatimEventDate': '2025/03/28 16:31',
#    'collectionCode': 'Observations',
#    'gbifID': '5108383907',
#    'verbatimLocality': 'Hallein, Österreich',
#    'occurrenceID': 'https://www.inaturalist.org/observations/267529877',
#    'taxonID': '515519',
#    'http://unknown.org/captive_cultivated': 'wild',
#    'catalogNumber': '267529877',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '16:31:00+01:00',
#    'occurrenceRemarks': 'großer Bestand in Kalktuffquellflur',
#    'identificationID': '606497327'},
#   {'key': 5108391964,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T00:24:03.737+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480781668',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:27:51-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480781668',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781668/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480781699',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:28:23-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480781699',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781699/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480781711',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:29:04-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480781711',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781711/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/480781736',
#       'http://purl.org/dc/terms/created': '2025-03-28T16:28:59-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '480781736',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781736/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Roland Kaiser',
#       'http://purl.org/dc/terms/creator': 'Roland Kaiser',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-03-29T16:22:43',
#    'decimalLatitude': 47.523582,
#    'decimalLongitude': 13.44209,
#    'coordinateUncertaintyInMeters': 5.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Salzburg',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.1_2', 'name': 'Hallein'},
#     'level3': {'gid': 'AUT.5.1.3_2', 'name': 'Annaberg-Lungötz'}},
#    'year': 2025,
#    'month': 3,
#    'day': 28,
#    'eventDate': '2025-03-28T16:27',
#    'startDayOfYear': 87,
#    'endDayOfYear': 87,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-04-14T23:36:40.000+00:00',
#    'lastInterpreted': '2025-06-07T00:24:03.737+00:00',
#    'references': 'https://www.inaturalist.org/observations/267529885',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '267529885'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480781668',
#      'created': '2025-03-28T23:27:51.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781668/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480781711',
#      'created': '2025-03-28T23:29:04.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781711/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480781699',
#      'created': '2025-03-28T23:28:23.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781699/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/480781736',
#      'created': '2025-03-28T23:28:59.000+00:00',
#      'creator': 'Roland Kaiser',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc-sa/4.0/',
#      'rightsHolder': 'Roland Kaiser',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/480781736/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Roland Kaiser',
#    'identifiedBy': 'Roland Kaiser',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-2487-9289'}],
#    'identifiedByIDs': [{'type': 'ORCID',
#      'value': 'https://orcid.org/0000-0002-2487-9289'}],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'NORTH_AMERICA',
#    'rightsHolder': 'Roland Kaiser',
#    'identifier': '267529885',
#    'http://unknown.org/nick': 'roland_kaiser',
#    'verbatimEventDate': '2025/03/28 16:27',
#    'collectionCode': 'Observations',
#    'gbifID': '5108391964',
#    'verbatimLocality': 'Hallein, Österreich',
#    'occurrenceID': 'https://www.inaturalist.org/observations/267529885',
#    'taxonID': '515519',
#    'http://unknown.org/captive_cultivated': 'wild',
#    'catalogNumber': '267529885',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '16:27:00+01:00',
#    'occurrenceRemarks': 'großer Bestand in Kalktuffquellflur',
#    'identificationID': '606497338'},
#   {'key': 5138946343,
#    'datasetKey': '8a863029-f435-446a-821e-275f4f641165',
#    'publishingOrgKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'installationKey': 'a0e05292-3d09-4eae-9f83-02ae3516283c',
#    'hostingOrganizationKey': 'c8d737e0-2ff8-42e8-b8fc-6b805d26fc5f',
#    'publishingCountry': 'NL',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-05-27T18:08:05.893+00:00',
#    'lastParsed': '2025-05-27T22:34:52.687+00:00',
#    'crawlId': 151,
#    'extensions': {'http://rs.tdwg.org/ac/terms/Multimedia': [{'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/114933892.jpg',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/114933892',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Thomas Steinwender',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/elements/1.1/creator': 'Thomas Steinwender'},
#      {'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/114933893.jpg',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/114933893',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Thomas Steinwender',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/elements/1.1/creator': 'Thomas Steinwender'},
#      {'http://rs.tdwg.org/ac/terms/accessURI': 'https://observation.org/photos/114933894.jpg',
#       'http://purl.org/dc/terms/identifier': 'https://observation.org/photos/114933894',
#       'http://ns.adobe.com/xap/1.0/rights/Owner': 'Thomas Steinwender',
#       'http://purl.org/dc/elements/1.1/type': 'StillImage',
#       'http://purl.org/dc/elements/1.1/rights': 'http://creativecommons.org/licenses/by-nc-nd/4.0/legalcode',
#       'http://purl.org/dc/elements/1.1/format': 'image/jpeg',
#       'http://rs.tdwg.org/ac/terms/variantLiteral': 'Best Quality',
#       'http://purl.org/dc/elements/1.1/creator': 'Thomas Steinwender'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'individualCount': 1,
#    'occurrenceStatus': 'PRESENT',
#    'lifeStage': 'Unknown',
#    'taxonKey': 5374902,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374902,
#    'scientificName': 'Arabis soyeri subsp. subcoriacea (Gren.) Breistr.',
#    'acceptedScientificName': 'Arabis soyeri subsp. subcoriacea (Gren.) Breistr.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'infraspecificEpithet': 'subcoriacea',
#    'taxonRank': 'SUBSPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'decimalLatitude': 47.206815,
#    'decimalLongitude': 13.664672,
#    'coordinateUncertaintyInMeters': 64.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Salzburg',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.5_2', 'name': 'Tamsweg'},
#     'level3': {'gid': 'AUT.5.5.14_2', 'name': 'Weißpriach'}},
#    'year': 2025,
#    'month': 4,
#    'day': 25,
#    'eventDate': '2025-04-25',
#    'startDayOfYear': 115,
#    'endDayOfYear': 115,
#    'issues': ['TAXON_MATCH_FUZZY'],
#    'modified': '2025-04-25T19:09:00.000+00:00',
#    'lastInterpreted': '2025-05-27T22:34:52.687+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '346411698'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Thomas Steinwender',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Thomas Steinwender',
#      'identifier': 'https://observation.org/photos/114933892.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Thomas Steinwender',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Thomas Steinwender',
#      'identifier': 'https://observation.org/photos/114933893.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'creator': 'Thomas Steinwender',
#      'license': 'http://creativecommons.org/licenses/by-nc-nd/4.0/',
#      'rightsHolder': 'Thomas Steinwender',
#      'identifier': 'https://observation.org/photos/114933894.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'User 750721',
#    'samplingProtocol': 'unknown',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'EUROPE',
#    'rightsHolder': 'Stichting Observation International',
#    'identifier': '346411698',
#    'habitat': 'unknown',
#    'eventTime': '12:21',
#    'locality': 'Weißpriach',
#    'identificationVerificationStatus': 'Approved | Expert | Evidence',
#    'gbifID': '5138946343',
#    'eventType': 'Observation',
#    'occurrenceID': 'https://observation.org/observation/346411698'},
#   {'key': 5153818372,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T00:37:44.893+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504034064',
#       'http://purl.org/dc/terms/created': '2025-05-11T13:07:41-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504034064',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034064/original.jpeg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504034109',
#       'http://purl.org/dc/terms/created': '2025-05-11T13:07:57-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504034109',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034109/original.jpeg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504034259',
#       'http://purl.org/dc/terms/created': '2025-05-11T13:08:08-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504034259',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034259/original.jpeg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-05-12T21:18:46',
#    'decimalLatitude': 47.147861,
#    'decimalLongitude': 11.577597,
#    'coordinateUncertaintyInMeters': 7.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Tirol',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.7_1', 'name': 'Tirol'},
#     'level2': {'gid': 'AUT.7.2_2', 'name': 'Innsbruck Land'},
#     'level3': {'gid': 'AUT.7.2.31_2', 'name': 'Navis'}},
#    'year': 2025,
#    'month': 5,
#    'day': 11,
#    'eventDate': '2025-05-11T13:07:36',
#    'startDayOfYear': 131,
#    'endDayOfYear': 131,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-05-13T06:52:35.000+00:00',
#    'lastInterpreted': '2025-06-07T00:37:44.893+00:00',
#    'references': 'https://www.inaturalist.org/observations/280627592',
#    'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '280627592'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504034259',
#      'created': '2025-05-11T20:08:08.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034259/original.jpeg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504034064',
#      'created': '2025-05-11T20:07:41.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034064/original.jpeg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504034109',
#      'created': '2025-05-11T20:07:57.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504034109/original.jpeg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Jens Bokelaar',
#    'identifiedBy': 'Jens Bokelaar',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'NORTH_AMERICA',
#    'rightsHolder': 'Jens Bokelaar',
#    'identifier': '280627592',
#    'http://unknown.org/nick': 'jensbokelaar',
#    'verbatimEventDate': '2025-05-11 13:07:36',
#    'collectionCode': 'Observations',
#    'gbifID': '5153818372',
#    'verbatimLocality': 'Navis, 6145 Navis, Austria',
#    'occurrenceID': 'https://www.inaturalist.org/observations/280627592',
#    'taxonID': '515519',
#    'http://unknown.org/captive_cultivated': 'wild',
#    'catalogNumber': '280627592',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '13:07:36+02:00',
#    'identificationID': '630972287'},
#   {'key': 5166900690,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T01:12:07.710+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504868868',
#       'http://purl.org/dc/terms/created': '2025-05-14T16:22:31-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504868868',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868868/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'leo_mrn',
#       'http://purl.org/dc/terms/creator': 'leo_mrn',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504868789',
#       'http://purl.org/dc/terms/created': '2025-05-14T16:22:34-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504868789',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868789/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'leo_mrn',
#       'http://purl.org/dc/terms/creator': 'leo_mrn',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504868795',
#       'http://purl.org/dc/terms/created': '2025-05-14T16:22:38-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504868795',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868795/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'leo_mrn',
#       'http://purl.org/dc/terms/creator': 'leo_mrn',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-05-14T18:11:19',
#    'decimalLatitude': 46.555962,
#    'decimalLongitude': 9.31953,
#    'coordinateUncertaintyInMeters': 43.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Graubünden',
#    'gadm': {'level0': {'gid': 'CHE', 'name': 'Switzerland'},
#     'level1': {'gid': 'CHE.10_1', 'name': 'Graubünden'},
#     'level2': {'gid': 'CHE.10.3_1', 'name': 'Hinterrhein'},
#     'level3': {'gid': 'CHE.10.3.29_1', 'name': 'Splügen'}},
#    'year': 2025,
#    'month': 5,
#    'day': 14,
#    'eventDate': '2025-05-14T16:22:31',
#    'startDayOfYear': 134,
#    'endDayOfYear': 134,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-05-16T12:31:52.000+00:00',
#    'lastInterpreted': '2025-06-07T01:12:07.710+00:00',
#    'references': 'https://www.inaturalist.org/observations/281070198',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '281070198'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504868868',
#      'created': '2025-05-14T23:22:31.000+00:00',
#      'creator': 'leo_mrn',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'leo_mrn',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868868/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504868795',
#      'created': '2025-05-14T23:22:38.000+00:00',
#      'creator': 'leo_mrn',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'leo_mrn',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868795/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504868789',
#      'created': '2025-05-14T23:22:34.000+00:00',
#      'creator': 'leo_mrn',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'leo_mrn',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504868789/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'leo_mrn',
#    'identifiedBy': 'leo_mrn',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'CH',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Switzerland',
#    'publishedByGbifRegion': 'NORTH_AMERICA',
#    'rightsHolder': 'leo_mrn',
#    'identifier': '281070198',
#    'http://unknown.org/nick': 'leo_mrn',
#    'verbatimEventDate': '2025-05-14 16:22:31',
#    'collectionCode': 'Observations',
#    'gbifID': '5166900690',
#    'verbatimLocality': 'Alpenpässe Weg, Splügen, GR, CH',
#    'occurrenceID': 'https://www.inaturalist.org/observations/281070198',
#    'taxonID': '515519',
#    'http://unknown.org/captive_cultivated': 'wild',
#    'catalogNumber': '281070198',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '16:22:31+02:00',
#    'identificationID': '631882465'},
#   {'key': 5167083028,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T01:09:18.694+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504939894',
#       'http://purl.org/dc/terms/created': '2025-05-10T18:43:17-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504939894',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939894/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504939932',
#       'http://purl.org/dc/terms/created': '2025-05-10T18:43:55-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504939932',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939932/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/504939971',
#       'http://purl.org/dc/terms/created': '2025-05-10T18:44:15-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '504939971',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939971/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/creator': 'Jens Bokelaar',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-05-14T21:03:40',
#    'decimalLatitude': 47.385296,
#    'decimalLongitude': 11.271513,
#    'coordinateUncertaintyInMeters': 951.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Tirol',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.7_1', 'name': 'Tirol'},
#     'level2': {'gid': 'AUT.7.2_2', 'name': 'Innsbruck Land'},
#     'level3': {'gid': 'AUT.7.2.47_2', 'name': 'Scharnitz'}},
#    'year': 2025,
#    'month': 5,
#    'day': 10,
#    'eventDate': '2025-05-10T18:43:14',
#    'startDayOfYear': 130,
#    'endDayOfYear': 130,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-05-16T12:29:51.000+00:00',
#    'lastInterpreted': '2025-06-07T01:09:18.694+00:00',
#    'references': 'https://www.inaturalist.org/observations/281107235',
#    'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '281107235'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504939894',
#      'created': '2025-05-11T01:43:17.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939894/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504939971',
#      'created': '2025-05-11T01:44:15.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939971/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/504939932',
#      'created': '2025-05-11T01:43:55.000+00:00',
#      'creator': 'Jens Bokelaar',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by-nc/4.0/',
#      'rightsHolder': 'Jens Bokelaar',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/504939932/original.jpg'}],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetName': 'iNaturalist research-grade observations',
#    'recordedBy': 'Jens Bokelaar',
#    'identifiedBy': 'Jens Bokelaar',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'NORTH_AMERICA',
#    'rightsHolder': 'Jens Bokelaar',
#    'identifier': '281107235',
#    'http://unknown.org/nick': 'jensbokelaar',
#    'verbatimEventDate': '2025-05-10 18:43:14',
#    'collectionCode': 'Observations',
#    'gbifID': '5167083028',
#    'verbatimLocality': 'Scharnitz, 6108, Austria',
#    'occurrenceID': 'https://www.inaturalist.org/observations/281107235',
#    'taxonID': '515519',
#    'http://unknown.org/captive_cultivated': 'wild',
#    'catalogNumber': '281107235',
#    'institutionCode': 'iNaturalist',
#    'eventTime': '18:43:14+02:00',
#    'identificationID': '631955909'},
#   {'key': 5168373747,
#    'datasetKey': '50c9509d-22c7-4a22-a47d-8c48425ef4a7',
#    'publishingOrgKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'installationKey': '997448a8-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '28eb1a3f-1c15-4a95-931a-4af90ecb574d',
#    'publishingCountry': 'US',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-06-06T14:41:08.836+00:00',
#    'lastParsed': '2025-06-07T02:00:04.063+00:00',
#    'crawlId': 548,
#    'extensions': {'http://rs.gbif.org/terms/1.0/Multimedia': [{'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/507419141',
#       'http://purl.org/dc/terms/created': '2025-05-18T10:49:43-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '507419141',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419141/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Thomas Ebner',
#       'http://purl.org/dc/terms/creator': 'Thomas Ebner',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/507419147',
#       'http://purl.org/dc/terms/created': '2025-05-18T10:49:49-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '507419147',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419147/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Thomas Ebner',
#       'http://purl.org/dc/terms/creator': 'Thomas Ebner',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/507419184',
#       'http://purl.org/dc/terms/created': '2025-05-18T10:50:03-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '507419184',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419184/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Thomas Ebner',
#       'http://purl.org/dc/terms/creator': 'Thomas Ebner',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/507419215',
#       'http://purl.org/dc/terms/created': '2025-05-18T10:50:08-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '507419215',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419215/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Thomas Ebner',
#       'http://purl.org/dc/terms/creator': 'Thomas Ebner',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'},
#      {'http://purl.org/dc/terms/references': 'https://www.inaturalist.org/photos/507419239',
#       'http://purl.org/dc/terms/created': '2025-05-18T10:50:13-07:00',
#       'http://rs.tdwg.org/dwc/terms/catalogNumber': '507419239',
#       'http://purl.org/dc/terms/identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419239/original.jpg',
#       'http://purl.org/dc/terms/format': 'image/jpeg',
#       'http://purl.org/dc/terms/rightsHolder': 'Thomas Ebner',
#       'http://purl.org/dc/terms/creator': 'Thomas Ebner',
#       'http://purl.org/dc/terms/license': 'http://creativecommons.org/licenses/by/4.0/',
#       'http://purl.org/dc/terms/type': 'StillImage',
#       'http://purl.org/dc/terms/publisher': 'iNaturalist'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374901,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374901,
#    'scientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'acceptedScientificName': 'Arabis soyeri Reut. & A.Huet.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'iucnRedListCategory': 'NE',
#    'dateIdentified': '2025-05-19T18:09:25',
#    'decimalLatitude': 47.768044,
#    'decimalLongitude': 13.484789,
#    'coordinateUncertaintyInMeters': 31.0,
#    'continent': 'EUROPE',
#    'stateProvince': 'Oberösterreich',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.4_1', 'name': 'Oberösterreich'},
#     'level2': {'gid': 'AUT.4.4_2', 'name': 'Gmunden'},
#     'level3': {'gid': 'AUT.4.4.17_2',
#      'name': 'Sankt Wolfgang im Salzkammergut'}},
#    'year': 2025,
#    'month': 5,
#    'day': 18,
#    'eventDate': '2025-05-18T10:49',
#    'startDayOfYear': 138,
#    'endDayOfYear': 138,
#    'issues': ['COORDINATE_ROUNDED',
#     'CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'modified': '2025-05-19T19:06:51.000+00:00',
#    'lastInterpreted': '2025-06-07T02:00:04.063+00:00',
#    'references': 'https://www.inaturalist.org/observations/282431713',
#    'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '282431713'}],
#    'media': [{'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/507419147',
#      'created': '2025-05-18T17:49:49.000+00:00',
#      'creator': 'Thomas Ebner',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by/4.0/',
#      'rightsHolder': 'Thomas Ebner',
#      'identifier': 'https://inaturalist-open-data.s3.amazonaws.com/photos/507419147/original.jpg'},
#     {'type': 'StillImage',
#      'format': 'image/jpeg',
#      'references': 'https://www.inaturalist.org/photos/507419239',
#      'created': '2025-05-18T17:50:13.000+00:00',
#      'creator': 'Thomas Ebner',
#      'publisher': 'iNaturalist',
#      'license': 'http://creativecommons.org/licenses/by/4.0/',
#      'rightsHolder': 'Thomas Ebner',
# ...
#    'catalogNumber': '3074583',
#    'institutionCode': 'HNS',
#    'locality': 'Untertauern',
#    'fieldNumber': 'OBS.280124781',
#    'gbifID': '4423141391',
#    'collectionCode': 'Biodiversitätsdatenbank Salzburg',
#    'occurrenceID': '6B211021-27F2-4C4B-9B5A-A1552E0C11DF',
#    'higherClassification': 'Brassicaceae'},
#   {'key': 4423089537,
#    'datasetKey': 'c1492854-5d15-40e9-9ee7-24a18ac05112',
#    'publishingOrgKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'installationKey': '6032a3a0-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'publishingCountry': 'AT',
#    'protocol': 'BIOCASE',
#    'lastCrawled': '2025-06-04T16:06:59.429+00:00',
#    'lastParsed': '2025-06-04T16:27:07.985+00:00',
#    'crawlId': 163,
#    'extensions': {'http://rs.tdwg.org/dwc/terms/MeasurementOrFact': [{'http://rs.tdwg.org/dwc/terms/measurementValue': '1',
#       'http://rs.tdwg.org/dwc/terms/measurementType': 'count'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374905,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374902,
#    'scientificName': 'Arabis bellidifolia Jacq.',
#    'acceptedScientificName': 'Arabis soyeri subsp. subcoriacea (Gren.) Breistr.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'bellidifolia',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'NE',
#    'decimalLatitude': 47.27,
#    'decimalLongitude': 13.47,
#    'coordinateUncertaintyInMeters': 1000.0,
#    'elevation': 1849.0,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.4_2', 'name': 'Sankt Johann im Pongau'},
#     'level3': {'gid': 'AUT.5.4.22_2', 'name': 'Untertauern'}},
#    'higherGeography': 'Salzburg',
#    'year': 2023,
#    'month': 7,
#    'day': 11,
#    'eventDate': '2023-07-11',
#    'startDayOfYear': 192,
#    'endDayOfYear': 192,
#    'issues': ['CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2024-10-23T13:20:21.513+00:00',
#    'lastInterpreted': '2025-06-04T16:27:07.985+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '3074587'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'ContactID: 4480',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'EUROPE',
#    'identifier': '3074587',
#    'catalogNumber': '3074587',
#    'institutionCode': 'HNS',
#    'locality': 'Untertauern',
#    'fieldNumber': 'OBS.280124614',
#    'gbifID': '4423089537',
#    'collectionCode': 'Biodiversitätsdatenbank Salzburg',
#    'occurrenceID': '04724742-123D-4712-AC96-3119C82F45E2',
#    'higherClassification': 'Brassicaceae'},
#   {'key': 4423162763,
#    'datasetKey': 'c1492854-5d15-40e9-9ee7-24a18ac05112',
#    'publishingOrgKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'installationKey': '6032a3a0-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'publishingCountry': 'AT',
#    'protocol': 'BIOCASE',
#    'lastCrawled': '2025-06-04T16:06:59.429+00:00',
#    'lastParsed': '2025-06-04T16:26:55.112+00:00',
#    'crawlId': 163,
#    'extensions': {'http://rs.tdwg.org/dwc/terms/MeasurementOrFact': [{'http://rs.tdwg.org/dwc/terms/measurementValue': '1',
#       'http://rs.tdwg.org/dwc/terms/measurementType': 'count'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374905,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374902,
#    'scientificName': 'Arabis bellidifolia Jacq.',
#    'acceptedScientificName': 'Arabis soyeri subsp. subcoriacea (Gren.) Breistr.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'bellidifolia',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'NE',
#    'decimalLatitude': 47.07,
#    'decimalLongitude': 13.01,
#    'coordinateUncertaintyInMeters': 1000.0,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.6_2', 'name': 'Zell am See'},
#     'level3': {'gid': 'AUT.5.6.17_2', 'name': 'Rauris'}},
#    'higherGeography': 'Salzburg',
#    'year': 2023,
#    'month': 7,
#    'day': 17,
#    'eventDate': '2023-07-17',
#    'startDayOfYear': 198,
#    'endDayOfYear': 198,
#    'issues': ['CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2024-10-23T13:20:21.513+00:00',
#    'lastInterpreted': '2025-06-04T16:26:55.112+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '3116537'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'ContactID: 2786',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'EUROPE',
#    'identifier': '3116537',
#    'catalogNumber': '3116537',
#    'institutionCode': 'HNS',
#    'locality': 'Rauris',
#    'fieldNumber': 'OBS.282706036',
#    'gbifID': '4423162763',
#    'collectionCode': 'Biodiversitätsdatenbank Salzburg',
#    'occurrenceID': '6102E48A-53EF-44FB-B2BB-39ACC4CE3D2F',
#    'higherClassification': 'Brassicaceae'},
#   {'key': 4920820767,
#    'datasetKey': 'c1492854-5d15-40e9-9ee7-24a18ac05112',
#    'publishingOrgKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'installationKey': '6032a3a0-f762-11e1-a439-00145eb45e9a',
#    'hostingOrganizationKey': '7a070ba0-bafb-11d9-8e53-b8a03c50a862',
#    'publishingCountry': 'AT',
#    'protocol': 'BIOCASE',
#    'lastCrawled': '2025-06-04T16:06:59.429+00:00',
#    'lastParsed': '2025-06-04T16:26:43.846+00:00',
#    'crawlId': 163,
#    'extensions': {'http://rs.tdwg.org/dwc/terms/MeasurementOrFact': [{'http://rs.tdwg.org/dwc/terms/measurementValue': '1',
#       'http://rs.tdwg.org/dwc/terms/measurementType': 'count'}]},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 5374905,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 5374902,
#    'scientificName': 'Arabis bellidifolia Jacq.',
#    'acceptedScientificName': 'Arabis soyeri subsp. subcoriacea (Gren.) Breistr.',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'bellidifolia',
#    'taxonRank': 'SPECIES',
#    'taxonomicStatus': 'SYNONYM',
#    'iucnRedListCategory': 'NE',
#    'decimalLatitude': 47.06,
#    'decimalLongitude': 13.55,
#    'coordinateUncertaintyInMeters': 1000.0,
#    'elevation': 2469.0,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'AUT', 'name': 'Austria'},
#     'level1': {'gid': 'AUT.5_1', 'name': 'Salzburg'},
#     'level2': {'gid': 'AUT.5.5_2', 'name': 'Tamsweg'},
#     'level3': {'gid': 'AUT.5.5.5_2', 'name': 'Muhr'}},
#    'higherGeography': 'Salzburg',
#    'year': 2023,
#    'month': 7,
#    'day': 11,
#    'eventDate': '2023-07-11',
#    'startDayOfYear': 192,
#    'endDayOfYear': 192,
#    'issues': ['CONTINENT_DERIVED_FROM_COORDINATES'],
#    'modified': '2024-10-23T13:20:21.513+00:00',
#    'lastInterpreted': '2025-06-04T16:26:43.846+00:00',
#    'license': 'http://creativecommons.org/licenses/by-nc/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '3273877'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'recordedBy': 'ContactID: 2786',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'AT',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'Austria',
#    'publishedByGbifRegion': 'EUROPE',
#    'identifier': '3273877',
#    'catalogNumber': '3273877',
#    'institutionCode': 'HNS',
#    'locality': 'Rennweg',
#    'fieldNumber': 'OBS.280116083',
#    'gbifID': '4920820767',
#    'collectionCode': 'Biodiversitätsdatenbank Salzburg',
#    'occurrenceID': '1196F51C-4F15-48C6-A844-6A6C4B802AD2',
#    'higherClassification': 'Brassicaceae'},
#   {'key': 4587923450,
#    'datasetKey': '605ae9d2-e439-40d9-bf0c-767181e929d5',
#    'publishingOrgKey': '1928bdf0-f5d2-11dc-8c12-b8a03c50a862',
#    'installationKey': 'e44d0fd7-0edf-477f-aa82-50a81836ab46',
#    'hostingOrganizationKey': '1928bdf0-f5d2-11dc-8c12-b8a03c50a862',
#    'publishingCountry': 'FR',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-01-19T00:49:24.822+00:00',
#    'lastParsed': '2025-01-31T21:09:18.386+00:00',
#    'crawlId': 1,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 7225598,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 7225598,
#    'scientificName': 'Arabis soyeri subsp. soyeri',
#    'acceptedScientificName': 'Arabis soyeri subsp. soyeri',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'infraspecificEpithet': 'soyeri',
#    'taxonRank': 'SUBSPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'decimalLatitude': 42.6491,
#    'decimalLongitude': 2.00619,
#    'coordinateUncertaintyInMeters': 10.0,
#    'elevation': 2211.0,
#    'elevationAccuracy': 183.0,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'FRA', 'name': 'France'},
#     'level1': {'gid': 'FRA.11_1', 'name': 'Occitanie'},
#     'level2': {'gid': 'FRA.11.11_1', 'name': 'Pyrénées-Orientales'},
#     'level3': {'gid': 'FRA.11.11.3_1', 'name': 'Prades'}},
#    'year': 2023,
#    'month': 7,
#    'day': 5,
#    'eventDate': '2023-07-05',
#    'startDayOfYear': 186,
#    'endDayOfYear': 186,
#    'issues': ['CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'lastInterpreted': '2025-01-31T21:09:18.386+00:00',
#    'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': '67b83a0b-28ab-4717-aa83-2bd9bd7d34c0'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetID': '4fdb7a9a-6caf-41d2-ae4f-51f6783117a2',
#    'recordedBy': 'MOLINA James (Conservatoire botanique national méditerranéen de Porquerolles)|BURKHART Julie-Anne (Conservatoire botanique national méditerranéen de Porquerolles)',
#    'identifiedBy': 'BURKHART Julie-Anne (Conservatoire botanique national méditerranéen de Porquerolles)',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'FR',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'France',
#    'publishedByGbifRegion': 'EUROPE',
#    'eventID': '67b83a0b-28ab-4717-aa83-2bd9bd7d34c0',
#    'identifier': '67b83a0b-28ab-4717-aa83-2bd9bd7d34c0',
#    'http://unknown.org/language': 'fr | en',
#    'footprintWKT': 'POINT(2.006189947640433 42.64909995663766)',
#    'municipality': 'Fontrabiouse',
#    'originalNameUsage': 'Arabis soyeri subsp. soyeri Reut. & A.L.P.Huet, 1853',
#    'county': 'Pyrénées-Orientales',
#    'identificationVerificationStatus': 'Probable',
#    'gbifID': '4587923450',
#    'nameAccordingTo': 'Gargominy O (2021). TAXREF. Version 4.7. UMS PatriNat (OFB-CNRS-MNHN), Paris. Checklist dataset https://doi.org/10.15468/vqueam accessed via GBIF.org on 2021-06-28.',
#    'occurrenceID': '67b83a0b-28ab-4717-aa83-2bd9bd7d34c0',
#    'taxonID': '131559'},
#   {'key': 4587877537,
#    'datasetKey': '605ae9d2-e439-40d9-bf0c-767181e929d5',
#    'publishingOrgKey': '1928bdf0-f5d2-11dc-8c12-b8a03c50a862',
#    'installationKey': 'e44d0fd7-0edf-477f-aa82-50a81836ab46',
#    'hostingOrganizationKey': '1928bdf0-f5d2-11dc-8c12-b8a03c50a862',
#    'publishingCountry': 'FR',
#    'protocol': 'DWC_ARCHIVE',
#    'lastCrawled': '2025-01-19T00:49:24.822+00:00',
#    'lastParsed': '2025-01-31T21:09:17.633+00:00',
#    'crawlId': 1,
#    'extensions': {},
#    'basisOfRecord': 'HUMAN_OBSERVATION',
#    'occurrenceStatus': 'PRESENT',
#    'taxonKey': 7225598,
#    'kingdomKey': 6,
#    'phylumKey': 7707728,
#    'classKey': 220,
#    'orderKey': 7225535,
#    'familyKey': 3112,
#    'genusKey': 5374837,
#    'speciesKey': 5374901,
#    'acceptedTaxonKey': 7225598,
#    'scientificName': 'Arabis soyeri subsp. soyeri',
#    'acceptedScientificName': 'Arabis soyeri subsp. soyeri',
#    'kingdom': 'Plantae',
#    'phylum': 'Tracheophyta',
#    'order': 'Brassicales',
#    'family': 'Brassicaceae',
#    'genus': 'Arabis',
#    'species': 'Arabis soyeri',
#    'genericName': 'Arabis',
#    'specificEpithet': 'soyeri',
#    'infraspecificEpithet': 'soyeri',
#    'taxonRank': 'SUBSPECIES',
#    'taxonomicStatus': 'ACCEPTED',
#    'decimalLatitude': 42.6484,
#    'decimalLongitude': 2.00716,
#    'coordinateUncertaintyInMeters': 10.0,
#    'elevation': 2208.5,
#    'elevationAccuracy': 185.5,
#    'continent': 'EUROPE',
#    'gadm': {'level0': {'gid': 'FRA', 'name': 'France'},
#     'level1': {'gid': 'FRA.11_1', 'name': 'Occitanie'},
#     'level2': {'gid': 'FRA.11.11_1', 'name': 'Pyrénées-Orientales'},
#     'level3': {'gid': 'FRA.11.11.3_1', 'name': 'Prades'}},
#    'year': 2023,
#    'month': 7,
#    'day': 5,
#    'eventDate': '2023-07-05',
#    'startDayOfYear': 186,
#    'endDayOfYear': 186,
#    'issues': ['CONTINENT_DERIVED_FROM_COORDINATES',
#     'TAXON_MATCH_TAXON_ID_IGNORED'],
#    'lastInterpreted': '2025-01-31T21:09:17.633+00:00',
#    'license': 'http://creativecommons.org/licenses/by/4.0/legalcode',
#    'isSequenced': False,
#    'identifiers': [{'identifier': 'a5a24ce6-1241-4af4-a2a2-4cac4a4f6e59'}],
#    'media': [],
#    'facts': [],
#    'relations': [],
#    'isInCluster': False,
#    'datasetID': '4fdb7a9a-6caf-41d2-ae4f-51f6783117a2',
#    'recordedBy': 'MOLINA James (Conservatoire botanique national méditerranéen de Porquerolles)|BURKHART Julie-Anne (Conservatoire botanique national méditerranéen de Porquerolles)',
#    'identifiedBy': 'BURKHART Julie-Anne (Conservatoire botanique national méditerranéen de Porquerolles)',
#    'dnaSequenceID': [],
#    'geodeticDatum': 'WGS84',
#    'class': 'Magnoliopsida',
#    'countryCode': 'FR',
#    'recordedByIDs': [],
#    'identifiedByIDs': [],
#    'gbifRegion': 'EUROPE',
#    'country': 'France',
#    'publishedByGbifRegion': 'EUROPE',
#    'eventID': 'a5a24ce6-1241-4af4-a2a2-4cac4a4f6e59',
#    'identifier': 'a5a24ce6-1241-4af4-a2a2-4cac4a4f6e59',
#    'http://unknown.org/language': 'fr | en',
#    'footprintWKT': 'POINT(2.007159952560583 42.6484000021189)',
#    'municipality': 'Fontrabiouse',
#    'originalNameUsage': 'Arabis soyeri subsp. soyeri Reut. & A.L.P.Huet, 1853',
#    'county': 'Pyrénées-Orientales',
#    'identificationVerificationStatus': 'Probable',
#    'gbifID': '4587877537',
#    'nameAccordingTo': 'Gargominy O (2021). TAXREF. Version 4.7. UMS PatriNat (OFB-CNRS-MNHN), Paris. Checklist dataset https://doi.org/10.15468/vqueam accessed via GBIF.org on 2021-06-28.',
#    'occurrenceID': 'a5a24ce6-1241-4af4-a2a2-4cac4a4f6e59',
#    'taxonID': '131559'}],
#  'facets': []}

# %% [markdown]
# # Reading from CSV

# %%
with open("prototypeNames.csv", "r") as f:
    lines = f.readlines()
#[:-2] is to discard the new line character at the end of the line
#print(lines[0][:-2].split(","))
listOfNames = [line[:-2].split(",") for line in lines]
flatlist = list(itertools.chain.from_iterable(listOfNames))
print(len(flatlist))
#Remove empty strings from the list
nonEmpty = list(filter(None, flatlist))
#Remove redundant copies of species name and save unique names
uniqueNames = list(set(nonEmpty))
print(len(uniqueNames))
# Out:
# 226
# 213

# %%
def read_species_names(inpFile, inpPath="", sep=","):
    """
    A function to read in the names of different species of interest that are stored in a csv file.
    This function provides automatic formatting

    Args:
        inp_file (str): The name for the file containing all the species names
        inp_path (str, optional): Path where the input file is stored. The default is empty and will be read from the working directory
        sep (str, optional): The separator character used in between species names. The standard used is ',', i.e. comma separated values
    Returns:
        species_names (pd.Dataframe): A dataframe containing all the relevant information stored in the GBIF taxonomic backbone
    """
    with open(os.path.join(inpPath, inpFile), "r") as f:
        fileLines = f.readlines()
    #Read lines up until second last character to drop '\n' new line command
    #Split the lines based on the used separator in the file
    species_names = [line[:-2].split(sep) for line in fileLines]
    #Convert list of lists into a single list
    species_names = list(itertools.chain.from_iterable(species_names))
    #Trim whitespace from the names
    species_names = [name.strip() for name in species_names]
    #Remove the empty elements from the list
    species_names = list(filter(None, species_names))
    #Remove duplicates and return list of unique species
    return list(set(species_names))

# %%
test = read_species_names("prototypeNames.csv")
len(test)
# Out:
# 211

# %%
def fetch_taxon_info(inp_file, inp_path="", 
                     out_file="", 
                     out_path="", 
                     sep=",", 
                     mismatch_file= "", 
                     keep_higherrank=False):
    """
    A function that reads in a list of species names and than retrieves all the relevant information from
    the GBIF taxonomic backbone. 

    Args:
        inp_file (str): The name for the file containing all the species names
        inp_path (str, optional): Path where the input file is stored. The default is empty and will be read from the working directory
        out_file (str): The name for the file to which the taxonomic information will be written to. If nothing is provided than the result will not be saved
        out_path (str, optional): Path where the output file will be stored. The default is empty and will be written to the working directory
        sep (str, optional): Separator used in the input file in between species names
        mismatch_file (str, optional): File where all the mismatched names should be written to together with the note of the name_backbone function
        keep_higherrank (bool, optional): Boolean option that allows the removal of higherrank matches in the GBIF taxonomic backbone
    Returns:
        taxonomic_df, mismatch_df (pd.Dataframe): A pair of dataframes containing all the relevant information stored in the GBIF taxonomic backbone. The first dataframe is the dataframe with valid matches whereas the second one contains all erroneous matches
    """
    #Retrieve names from the file
    species_names = read_species_names(inp_file, inp_path, sep=sep)
    #Retrieve information from the GBIF taxonomic backbone
    taxonomic_info = list(map(pygbif.species.name_backbone, species_names))
    #Convert the list of dictionaries to dataframe
    taxonomic_df = pd.DataFrame(taxonomic_info)
    taxonomic_df["lookupNames"] = species_names
    #Extract rows that are None matches and if enabled higherrank matches
    mismatch_df = None
    if keep_higherrank == True:
        #Lookup 'NONE' matches in the df and get the indices
        mismatch_indices = taxonomic_df.index[taxonomic_df['matchType'] == "NONE"].tolist()
        #Copy mismatched to separate df
        mismatch_df = taxonomic_df.iloc[mismatch_indices] 
        #Remove mismatches from original df
        taxonomic_df.drop(mismatch_indices, inplace = True)
        warning_msg = "'NONE' matches encountered while searching through the GBIF taxonomic backbone:\nThe following lookup names ("
        warning_msg += ", ".join(mismatch_df["lookupNames"].tolist())
        warning_msg += ") resulted in 'NONE' type match. Potential reasons can be found in the mismatch_df under the key 'note'"
        print(warning_msg)
    else:
        mismatch_indices = taxonomic_df.index[(taxonomic_df['matchType'] == "NONE") | (taxonomic_df['matchType'] == "HIGHERRANK")].tolist()
        mismatch_df = taxonomic_df.iloc[mismatch_indices] 
        taxonomic_df.drop(mismatch_indices, inplace = True)
        warning_msg = "'NONE' and 'HIGHERRANK' matches encountered while searching through the GBIF taxonomic backbone:\nThe following lookup names ("
        warning_msg += ", ".join(mismatch_df["lookupNames"].tolist())
        warning_msg += ") resulted in 'NONE' or 'HIGHERRANK' type match. Potential reasons can be found in the mismatch_df under the key 'note'"
        print(warning_msg)
    #Assert that usageKeys are cast as integers
    taxonomic_df["usageKey"] = taxonomic_df[key].astype(int)
    #If an out_file is specified than the taxonomic info will be written to a file of said name
    if out_file != "":
        taxonomic_df.to_csv(os.path.join(out_path, out_file), index=False)
    return taxonomic_df, mismatch_df

# %%
df1, df2 = fetch_taxon_info("prototypeNames.csv")
# Out:
# 'NONE' and 'HIGHERRANK' matches encountered while searching through the GBIF taxonomic backbone:
# The following lookup names (Carex sp., Salix alba, Lathyrus montanus, Lotus uliginosus, Chara sp, Ranunculus nemorosus) resulted in 'NONE' or 'HIGHERRANK' type match. Potential reasons can be found in the mismatch_df under the key 'note'

# %%
df1
# Out:
#      usageKey                  scientificName           canonicalName  \
# 0     8229935            Inula salicina Pall.          Inula salicina
# 1    11071158           Stellaria holostea L.      Stellaria holostea
# 2     2914547              Galium saxatile L.         Galium saxatile
# 3     2890668         Geranium robertianum L.    Geranium robertianum
# 4     6027328       Chaerophyllum hirsutum L.  Chaerophyllum hirsutum
# ..        ...                             ...                     ...
# 206   3135329         Hieracium umbellatum L.    Hieracium umbellatum
# 207   2475532  Alcedo atthis (Linnaeus, 1758)           Alcedo atthis
# 208   6026490         Meum athamanticum Jacq.       Meum athamanticum
# 209   3033289           Trollius europaeus L.      Trollius europaeus
# 210   2704951                Festuca ovina L.           Festuca ovina
#
#         rank    status  confidence matchType   kingdom        phylum  \
# 0    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 1    SPECIES   SYNONYM          98     EXACT   Plantae  Tracheophyta
# 2    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 3    SPECIES  ACCEPTED          99     EXACT   Plantae  Tracheophyta
# 4    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# ..       ...       ...         ...       ...       ...           ...
# 206  SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 207  SPECIES  ACCEPTED          99     EXACT  Animalia      Chordata
# 208  SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 209  SPECIES  ACCEPTED          94     FUZZY   Plantae  Tracheophyta
# 210  SPECIES  ACCEPTED          98     EXACT   Plantae  Tracheophyta
#
#               order  ... classKey orderKey familyKey    genusKey  speciesKey  \
# 0         Asterales  ...    220.0    414.0    3065.0   3148323.0   8229935.0
# 1    Caryophyllales  ...    220.0    422.0    2518.0  11086674.0  11071158.0
# 2       Gentianales  ...    220.0    412.0    8798.0   2913027.0   2914547.0
# 3        Geraniales  ...    220.0    624.0    4676.0   2889949.0   2890668.0
# 4           Apiales  ...    220.0   1351.0    6720.0   3034649.0   6027328.0
# ..              ...  ...      ...      ...       ...         ...         ...
# 206       Asterales  ...    220.0    414.0    3065.0   3134951.0   3135329.0
# 207   Coraciiformes  ...    212.0   1447.0    2984.0   2475493.0   2475532.0
# 208         Apiales  ...    220.0   1351.0    6720.0   6026466.0   6026490.0
# 209    Ranunculales  ...    220.0    399.0    2410.0   3033288.0   3033289.0
# 210          Poales  ...    196.0   1369.0    3073.0   2704913.0   2704951.0
#
#      synonym          class  acceptedUsageKey  note             lookupNames
# 0      False  Magnoliopsida               NaN   NaN          Inula salicina
# 1       True  Magnoliopsida        11071158.0   NaN      Stellaria holostea
# 2      False  Magnoliopsida               NaN   NaN         Galium saxatile
# 3      False  Magnoliopsida               NaN   NaN    Geranium robertianum
# 4      False  Magnoliopsida               NaN   NaN  Chaerophyllum hirsutum
# ..       ...            ...               ...   ...                     ...
# 206    False  Magnoliopsida               NaN   NaN    Hieracium umbellatum
# 207    False           Aves               NaN   NaN           Alcedo atthis
# 208    False  Magnoliopsida               NaN   NaN       Meum athamanticum
# 209    False  Magnoliopsida               NaN   NaN       Trollius europaeu
# 210    False     Liliopsida               NaN   NaN           Festuca ovina
#
# [205 rows x 25 columns]

# %%
df2
# Out:
#        usageKey scientificName  canonicalName    rank    status  confidence  \
# 27    2721893.0       Carex L.          Carex   GENUS  ACCEPTED          94
# 54          NaN            NaN            NaN     NaN       NaN         100
# 104  10356062.0    Lathyrus L.       Lathyrus   GENUS  ACCEPTED          97
# 166  10220564.0       Lotus L.          Lotus   GENUS  ACCEPTED          97
# 175         NaN            NaN            NaN     NaN       NaN         100
# 193      2410.0  Ranunculaceae  Ranunculaceae  FAMILY  ACCEPTED          97
#
#       matchType  kingdom        phylum         order  ... classKey orderKey  \
# 27   HIGHERRANK  Plantae  Tracheophyta        Poales  ...    196.0   1369.0
# 54         NONE      NaN           NaN           NaN  ...      NaN      NaN
# 104  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...    220.0   1370.0
# 166  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...    220.0   1370.0
# 175        NONE      NaN           NaN           NaN  ...      NaN      NaN
# 193  HIGHERRANK  Plantae  Tracheophyta  Ranunculales  ...    220.0    399.0
#
#     familyKey    genusKey  speciesKey  synonym          class  \
# 27     7708.0   2721893.0         NaN    False     Liliopsida
# 54        NaN         NaN         NaN    False            NaN
# 104    5386.0  10356062.0         NaN    False  Magnoliopsida
# 166    5386.0  10220564.0         NaN    False  Magnoliopsida
# 175       NaN         NaN         NaN    False            NaN
# 193    2410.0         NaN         NaN    False  Magnoliopsida
#
#      acceptedUsageKey                                   note  \
# 27                NaN                                    NaN
# 54                NaN  Multiple equal matches for Salix alba
# 104               NaN                                    NaN
# 166               NaN                                    NaN
# 175               NaN       Multiple equal matches for Chara
# 193               NaN                                    NaN
#
#               lookupNames
# 27              Carex sp.
# 54             Salix alba
# 104     Lathyrus montanus
# 166      Lotus uliginosus
# 175              Chara sp
# 193  Ranunculus nemorosus
#
# [6 rows x 25 columns]

# %%
", ".join(df2["lookupNames"].tolist())
# Out:
# 'Carex sp., Salix alba, Lathyrus montanus, Lotus uliginosus, Chara sp, Ranunculus nemorosus'

# %%
", ".join(df2["note"].tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 ", ".join(df2["note"].tolist())
#
# TypeError: sequence item 0: expected str instance, float found

# %%
df1["usageKey"].values.astype(int)
# Out:
# array([8229935, 5384676, 2914547, 2890668, 6027328, 2493129, 2675719,
#        2685484, 5369701, 2432452, 2926683, 2882833, 5374901, 5371874,
#        5301141, 3112651, 2676091, 2701939, 3136606, 5290081, 2927323,
#        5371781, 2702717, 2721983, 3033377, 5290194, 2727917, 3137498,
#        2875818, 5331355, 2360842, 4109084, 2676867, 2671130, 2477872,
#        5373255, 2729081, 3029627, 8848598, 5366922, 3087634, 2880130,
#        2432427, 1704195, 3172427, 2987999, 7972010, 3107845, 3152047,
#        3085424, 5284517, 3189103, 3152379, 2726592, 5301200, 3171712,
#        7702019, 2724609, 2963137, 7589456, 5663291, 3033266, 2478026,
#        5284884, 5371818, 5347644, 3085811, 2756540, 2681640, 5384795,
#        2874027, 2926901, 2700934, 2876213, 5301213, 3033675, 5365283,
#        3191374, 8214667, 5410564, 7502456, 2878688, 3189863, 2431885,
#        5403296, 5376075, 7531424, 3113777, 5306890, 3040227, 2480910,
#        2723099, 5341478, 5347824, 7270598, 5314725, 7277865, 9490132,
#        3012167, 5409958, 3093693, 3113650, 2480946, 2723315, 3189172,
#        3033665, 5414222, 3033682, 2882316, 4279712, 2891147, 8278445,
#        5347571, 5743122, 2676491, 5329266, 5331258, 2480726, 4567182,
#        4116392, 3190715, 5371808, 2727294, 8925249, 3034742, 2722051,
#        6363496, 3054168, 5329192, 5385604, 8397184, 2913288, 7693914,
#        5371889, 3034620, 9444556, 3039454, 2704211, 2878826, 3172049,
#        5334208, 2673131, 8165236, 2687943, 3033464, 4567215, 5333411,
#        7297904, 9213153, 2703179, 7960979, 8365713, 5334277, 3113784,
#        2769766, 2673408, 5304283, 5275012, 9118014, 6027388, 4126278,
#        2926557, 2739622, 3133702, 2888808, 5289877, 5365496, 2481819,
#        2704505, 6363434, 3128547, 2701418, 5331916, 3033263, 5386897,
#        4408732, 5405976, 2706163, 3046044, 3034230, 5414992, 2722602,
#        2882482, 5365576, 2481119, 5403531, 2913556, 2650133, 2480420,
#        2951998, 2873896, 2888960, 5333408, 2721897, 3169340, 2914642,
#        3040249, 3188736, 5388835, 5710895, 3135329, 2475532, 6026490,
#        3033289, 2704951])

# %%
df1["phylumKey"].values.astype(int)
# Out:
# array([7707728, 7707728, 7707728, 7707728, 7707728,      44,      35,
#        7707728, 7707728,      44, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728,      35, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728,      44, 7707728,      35,      35,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#             44,      54, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728,      35, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728,      44, 7707728, 7707728, 7707728, 7707728,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728,      44, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728,      35, 7707728, 7707728,
#        7707728,      54,      35, 7707728, 7707728,      44,      52,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728,      44, 7707728, 7707728, 7707728, 7707728,
#        7707728,      35, 7707728, 7707728, 7707728,      52, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728,      35, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#             44, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728,      44, 7707728, 7707728, 7707728,      44,
#        7707728, 7707728, 7707728, 7707728, 7707728, 7707728, 7707728,
#        7707728, 7707728, 7707728,      35, 7707728,      44, 7707728,
#        7707728, 7707728])

# %%
df1.loc[df1["classKey"].isna()]
# Out:
#      usageKey                scientificName   canonicalName     rank  \
# 31  2360842.0  Rhodeus amarus (Bloch, 1782)  Rhodeus amarus  SPECIES
#
#       status  confidence matchType   kingdom    phylum          order  ...  \
# 31  ACCEPTED          99     EXACT  Animalia  Chordata  Cypriniformes  ...
#
#    classKey orderKey familyKey   genusKey  speciesKey  synonym  class  \
# 31      NaN   1153.0    7336.0  2360802.0   2360842.0    False    NaN
#
#     acceptedUsageKey  note     lookupNames
# 31               NaN   NaN  Rhodeus amarus
#
# [1 rows x 25 columns]

# %%
df2
# Out:
#        usageKey scientificName  canonicalName    rank    status  confidence  \
# 27    2721893.0       Carex L.          Carex   GENUS  ACCEPTED          94
# 54          NaN            NaN            NaN     NaN       NaN         100
# 104  10356062.0    Lathyrus L.       Lathyrus   GENUS  ACCEPTED          97
# 166  10220564.0       Lotus L.          Lotus   GENUS  ACCEPTED          97
# 175         NaN            NaN            NaN     NaN       NaN         100
# 193      2410.0  Ranunculaceae  Ranunculaceae  FAMILY  ACCEPTED          97
#
#       matchType  kingdom        phylum         order  ... classKey orderKey  \
# 27   HIGHERRANK  Plantae  Tracheophyta        Poales  ...    196.0   1369.0
# 54         NONE      NaN           NaN           NaN  ...      NaN      NaN
# 104  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...    220.0   1370.0
# 166  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...    220.0   1370.0
# 175        NONE      NaN           NaN           NaN  ...      NaN      NaN
# 193  HIGHERRANK  Plantae  Tracheophyta  Ranunculales  ...    220.0    399.0
#
#     familyKey    genusKey  speciesKey  synonym          class  \
# 27     7708.0   2721893.0         NaN    False     Liliopsida
# 54        NaN         NaN         NaN    False            NaN
# 104    5386.0  10356062.0         NaN    False  Magnoliopsida
# 166    5386.0  10220564.0         NaN    False  Magnoliopsida
# 175       NaN         NaN         NaN    False            NaN
# 193    2410.0         NaN         NaN    False  Magnoliopsida
#
#      acceptedUsageKey                                   note  \
# 27                NaN                                    NaN
# 54                NaN  Multiple equal matches for Salix alba
# 104               NaN                                    NaN
# 166               NaN                                    NaN
# 175               NaN       Multiple equal matches for Chara
# 193               NaN                                    NaN
#
#               lookupNames
# 27              Carex sp.
# 54             Salix alba
# 104     Lathyrus montanus
# 166      Lotus uliginosus
# 175              Chara sp
# 193  Ranunculus nemorosus
#
# [6 rows x 25 columns]

# %%
df
# Out:
#       usageKey                  scientificName           canonicalName  \
# 0    8229935.0            Inula salicina Pall.          Inula salicina
# 1    5384676.0           Stellaria holostea L.      Stellaria holostea
# 2    2914547.0              Galium saxatile L.         Galium saxatile
# 3    2890668.0         Geranium robertianum L.    Geranium robertianum
# 4    6027328.0       Chaerophyllum hirsutum L.  Chaerophyllum hirsutum
# ..         ...                             ...                     ...
# 206  3135329.0         Hieracium umbellatum L.    Hieracium umbellatum
# 207  2475532.0  Alcedo atthis (Linnaeus, 1758)           Alcedo atthis
# 208  6026490.0         Meum athamanticum Jacq.       Meum athamanticum
# 209  3033289.0           Trollius europaeus L.      Trollius europaeus
# 210  2704951.0                Festuca ovina L.           Festuca ovina
#
#         rank    status  confidence matchType   kingdom        phylum  \
# 0    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 1    SPECIES   SYNONYM          98     EXACT   Plantae  Tracheophyta
# 2    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 3    SPECIES  ACCEPTED          99     EXACT   Plantae  Tracheophyta
# 4    SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# ..       ...       ...         ...       ...       ...           ...
# 206  SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 207  SPECIES  ACCEPTED          99     EXACT  Animalia      Chordata
# 208  SPECIES  ACCEPTED          97     EXACT   Plantae  Tracheophyta
# 209  SPECIES  ACCEPTED          94     FUZZY   Plantae  Tracheophyta
# 210  SPECIES  ACCEPTED          98     EXACT   Plantae  Tracheophyta
#
#               order  ... classKey orderKey familyKey    genusKey  speciesKey  \
# 0         Asterales  ...    220.0    414.0    3065.0   3148323.0   8229935.0
# 1    Caryophyllales  ...    220.0    422.0    2518.0  11086674.0  11071158.0
# 2       Gentianales  ...    220.0    412.0    8798.0   2913027.0   2914547.0
# 3        Geraniales  ...    220.0    624.0    4676.0   2889949.0   2890668.0
# 4           Apiales  ...    220.0   1351.0    6720.0   3034649.0   6027328.0
# ..              ...  ...      ...      ...       ...         ...         ...
# 206       Asterales  ...    220.0    414.0    3065.0   3134951.0   3135329.0
# 207   Coraciiformes  ...    212.0   1447.0    2984.0   2475493.0   2475532.0
# 208         Apiales  ...    220.0   1351.0    6720.0   6026466.0   6026490.0
# 209    Ranunculales  ...    220.0    399.0    2410.0   3033288.0   3033289.0
# 210          Poales  ...    196.0   1369.0    3073.0   2704913.0   2704951.0
#
#      synonym          class  acceptedUsageKey  note             lookupNames
# 0      False  Magnoliopsida               NaN   NaN          Inula salicina
# 1       True  Magnoliopsida        11071158.0   NaN      Stellaria holostea
# 2      False  Magnoliopsida               NaN   NaN         Galium saxatile
# 3      False  Magnoliopsida               NaN   NaN    Geranium robertianum
# 4      False  Magnoliopsida               NaN   NaN  Chaerophyllum hirsutum
# ..       ...            ...               ...   ...                     ...
# 206    False  Magnoliopsida               NaN   NaN    Hieracium umbellatum
# 207    False           Aves               NaN   NaN           Alcedo atthis
# 208    False  Magnoliopsida               NaN   NaN       Meum athamanticum
# 209    False  Magnoliopsida               NaN   NaN       Trollius europaeu
# 210    False     Liliopsida               NaN   NaN           Festuca ovina
#
# [211 rows x 25 columns]

# %%
set(df["matchType"].values)
# Out:
# {'EXACT', 'FUZZY', 'HIGHERRANK', 'NONE'}

# %%
df.index[df['matchType'] == "HIGHERRANK"].tolist()
# Out:
# [27, 104, 166, 193]

# %%
df.index[df['matchType'] == "NONE"].tolist()
# Out:
# [54, 175]

# %%
df.index[(df['matchType'] == "NONE")|(df['matchType'] == "HIGHERRANK")].tolist()
# Out:
# [27, 54, 104, 166, 175, 193]

# %%
test = None
mismatch_indices = df.index[df['matchType'] == "NONE"].tolist()
test = df.iloc[mismatch_indices]
test
# Out:
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... classKey orderKey familyKey  genusKey  \
# 54      NaN    NaN   NaN  ...      NaN      NaN       NaN       NaN
# 175     NaN    NaN   NaN  ...      NaN      NaN       NaN       NaN
#
#      speciesKey  synonym  class  acceptedUsageKey  \
# 54          NaN    False    NaN               NaN
# 175         NaN    False    NaN               NaN
#
#                                       note  lookupNames
# 54   Multiple equal matches for Salix alba   Salix alba
# 175       Multiple equal matches for Chara     Chara sp
#
# [2 rows x 25 columns]

# %%
df.drop(mismatch_indices, inplace = True)

# %%
df.head()
# Out:
#     usageKey             scientificName           canonicalName     rank  \
# 0  8229935.0       Inula salicina Pall.          Inula salicina  SPECIES
# 1  5384676.0      Stellaria holostea L.      Stellaria holostea  SPECIES
# 2  2914547.0         Galium saxatile L.         Galium saxatile  SPECIES
# 3  2890668.0    Geranium robertianum L.    Geranium robertianum  SPECIES
# 4  6027328.0  Chaerophyllum hirsutum L.  Chaerophyllum hirsutum  SPECIES
#
#      status  confidence matchType  kingdom        phylum           order  ...  \
# 0  ACCEPTED          97     EXACT  Plantae  Tracheophyta       Asterales  ...
# 1   SYNONYM          98     EXACT  Plantae  Tracheophyta  Caryophyllales  ...
# 2  ACCEPTED          97     EXACT  Plantae  Tracheophyta     Gentianales  ...
# 3  ACCEPTED          99     EXACT  Plantae  Tracheophyta      Geraniales  ...
# 4  ACCEPTED          97     EXACT  Plantae  Tracheophyta         Apiales  ...
#
#   classKey orderKey familyKey    genusKey  speciesKey  synonym          class  \
# 0    220.0    414.0    3065.0   3148323.0   8229935.0    False  Magnoliopsida
# 1    220.0    422.0    2518.0  11086674.0  11071158.0     True  Magnoliopsida
# 2    220.0    412.0    8798.0   2913027.0   2914547.0    False  Magnoliopsida
# 3    220.0    624.0    4676.0   2889949.0   2890668.0    False  Magnoliopsida
# 4    220.0   1351.0    6720.0   3034649.0   6027328.0    False  Magnoliopsida
#
#    acceptedUsageKey  note             lookupNames
# 0               NaN   NaN          Inula salicina
# 1        11071158.0   NaN      Stellaria holostea
# 2               NaN   NaN         Galium saxatile
# 3               NaN   NaN    Geranium robertianum
# 4               NaN   NaN  Chaerophyllum hirsutum
#
# [5 rows x 25 columns]

# %%
test
# Out:
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... classKey orderKey familyKey  genusKey  \
# 54      NaN    NaN   NaN  ...      NaN      NaN       NaN       NaN
# 175     NaN    NaN   NaN  ...      NaN      NaN       NaN       NaN
#
#      speciesKey  synonym  class  acceptedUsageKey  \
# 54          NaN    False    NaN               NaN
# 175         NaN    False    NaN               NaN
#
#                                       note  lookupNames
# 54   Multiple equal matches for Salix alba   Salix alba
# 175       Multiple equal matches for Chara     Chara sp
#
# [2 rows x 25 columns]

# %%
(df["matchType"]=="FUZZY").values
# Out:
# array([False, False, False, False, False, False, False, False, False,
#         True, False,  True, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False,  True, False, False, False,  True,  True, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False, False, False, False, False, False,
#        False, False, False, False,  True, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#         True, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False,  True,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True, False])

# %%
list(itertools.compress(test, (df["matchType"]=="FUZZY").values))
# Out:
# ['Myotis dasycnem',
#  'Vaccinium myrtillu',
#  'Utricularia vulgari',
#  'Tilia cordat',
#  'Viola persicifoli',
#  'Picea abie',
#  'Zannichellia palustri',
#  'Scorpidium revolven',
#  'Cistus salvifolius',
#  'Sorbus aucupari',
#  'Viola canin',
#  'Teesdalia nudicauli',
#  'Urtica dioic',
#  'Tragopogon pratensi',
#  'Ulex galli',
#  'Trollius europaeu']

# %%
df[["matchType", "note"]]
# Out:
#     matchType note
# 0       EXACT  NaN
# 1       EXACT  NaN
# 2       EXACT  NaN
# 3       EXACT  NaN
# 4       EXACT  NaN
# ..        ...  ...
# 206     EXACT  NaN
# 207     EXACT  NaN
# 208     EXACT  NaN
# 209     FUZZY  NaN
# 210     EXACT  NaN
#
# [211 rows x 2 columns]

# %%
df.iloc[pd.concat((df[df["matchType"]=="NONE"],df[df["matchType"]=="HIGHERRANK"])).index]
# Out:
#        usageKey scientificName  canonicalName    rank    status  confidence  \
# 54          NaN            NaN            NaN     NaN       NaN         100
# 175         NaN            NaN            NaN     NaN       NaN         100
# 27    2721893.0       Carex L.          Carex   GENUS  ACCEPTED          94
# 104  10356062.0    Lathyrus L.       Lathyrus   GENUS  ACCEPTED          97
# 166  10220564.0       Lotus L.          Lotus   GENUS  ACCEPTED          97
# 193      2410.0  Ranunculaceae  Ranunculaceae  FAMILY  ACCEPTED          97
#
#       matchType  kingdom        phylum         order  ...  phylumKey classKey  \
# 54         NONE      NaN           NaN           NaN  ...        NaN      NaN
# 175        NONE      NaN           NaN           NaN  ...        NaN      NaN
# 27   HIGHERRANK  Plantae  Tracheophyta        Poales  ...  7707728.0    196.0
# 104  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...  7707728.0    220.0
# 166  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...  7707728.0    220.0
# 193  HIGHERRANK  Plantae  Tracheophyta  Ranunculales  ...  7707728.0    220.0
#
#     orderKey  familyKey    genusKey  speciesKey  synonym          class  \
# 54       NaN        NaN         NaN         NaN    False            NaN
# 175      NaN        NaN         NaN         NaN    False            NaN
# 27    1369.0     7708.0   2721893.0         NaN    False     Liliopsida
# 104   1370.0     5386.0  10356062.0         NaN    False  Magnoliopsida
# 166   1370.0     5386.0  10220564.0         NaN    False  Magnoliopsida
# 193    399.0     2410.0         NaN         NaN    False  Magnoliopsida
#
#      acceptedUsageKey                                   note
# 54                NaN  Multiple equal matches for Salix alba
# 175               NaN       Multiple equal matches for Chara
# 27                NaN                                    NaN
# 104               NaN                                    NaN
# 166               NaN                                    NaN
# 193               NaN                                    NaN
#
# [6 rows x 24 columns]

# %%
list(itertools.compress(test, (df["matchType"]=="HIGHERRANK").values))
# Out:
# ['Carex sp.', 'Lathyrus montanus', 'Lotus uliginosus', 'Ranunculus nemorosus']

# %%
df[df["matchType"]=="HIGHERRANK"]
# Out:
#        usageKey scientificName  canonicalName    rank    status  confidence  \
# 27    2721893.0       Carex L.          Carex   GENUS  ACCEPTED          94
# 104  10356062.0    Lathyrus L.       Lathyrus   GENUS  ACCEPTED          97
# 166  10220564.0       Lotus L.          Lotus   GENUS  ACCEPTED          97
# 193      2410.0  Ranunculaceae  Ranunculaceae  FAMILY  ACCEPTED          97
#
#       matchType  kingdom        phylum         order  ...  phylumKey classKey  \
# 27   HIGHERRANK  Plantae  Tracheophyta        Poales  ...  7707728.0    196.0
# 104  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...  7707728.0    220.0
# 166  HIGHERRANK  Plantae  Tracheophyta       Fabales  ...  7707728.0    220.0
# 193  HIGHERRANK  Plantae  Tracheophyta  Ranunculales  ...  7707728.0    220.0
#
#     orderKey  familyKey    genusKey  speciesKey  synonym          class  \
# 27    1369.0     7708.0   2721893.0         NaN    False     Liliopsida
# 104   1370.0     5386.0  10356062.0         NaN    False  Magnoliopsida
# 166   1370.0     5386.0  10220564.0         NaN    False  Magnoliopsida
# 193    399.0     2410.0         NaN         NaN    False  Magnoliopsida
#
#      acceptedUsageKey  note
# 27                NaN   NaN
# 104               NaN   NaN
# 166               NaN   NaN
# 193               NaN   NaN
#
# [4 rows x 24 columns]

# %%
df[df["matchType"]=="NONE"]
# Out:
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]

# %%
intKeys = ["usageKey", "phylumKey", "classKey","orderKey", "familyKey",	"genusKey",	"speciesKey"]
for key in intKeys:
    print(df[df[intKeys[0]].isna()])
# Out:
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]
#      usageKey scientificName canonicalName rank status  confidence matchType  \
# 54        NaN            NaN           NaN  NaN    NaN         100      NONE
# 175       NaN            NaN           NaN  NaN    NaN         100      NONE
#
#     kingdom phylum order  ... phylumKey classKey orderKey  familyKey  \
# 54      NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
# 175     NaN    NaN   NaN  ...       NaN      NaN      NaN        NaN
#
#      genusKey  speciesKey  synonym  class  acceptedUsageKey  \
# 54        NaN         NaN    False    NaN               NaN
# 175       NaN         NaN    False    NaN               NaN
#
#                                       note
# 54   Multiple equal matches for Salix alba
# 175       Multiple equal matches for Chara
#
# [2 rows x 24 columns]

# %%
pygbif.species.name_backbone(name="Chara sp.")
# Out:
# {'confidence': 100,
#  'note': 'Multiple equal matches for Chara',
#  'matchType': 'NONE',
#  'synonym': False}

# %% [markdown]
# # Reading from darwincore archive

# %%
inpPath = "dwca-unified-checklist-v1.14/"
with open(os.path.join(inpPath, "taxon.txt"), "r", encoding="utf8") as f:
    lines=f.readlines()
lines = list(map(lambda x: x[:-2].split("\t"), lines))

# %%
inpPath = "dwca-unified-checklist-v1.14/"
df = pd.read_csv(os.path.join(inpPath, "taxon.txt"), sep="\t", encoding="utf8")
df.head()
# Out:
#                                       id  \
# 0   https://www.gbif.org/species/1002621
# 1   https://www.gbif.org/species/1003567
# 2  https://www.gbif.org/species/10071055
# 3   https://www.gbif.org/species/1007534
# 4   https://www.gbif.org/species/1008610
#
#                                  taxonID  \
# 0   https://www.gbif.org/species/1002621
# 1   https://www.gbif.org/species/1003567
# 2  https://www.gbif.org/species/10071055
# 3   https://www.gbif.org/species/1007534
# 4   https://www.gbif.org/species/1008610
#
#                               scientificName   kingdom        phylum  \
# 0          Keratella tropica (Apstein, 1907)  Animalia      Rotifera
# 1       Pectinatella magnifica (Leidy, 1851)  Animalia       Bryozoa
# 2  Scandosorbus ×intermedia (Ehrh.) Sennikov   Plantae  Tracheophyta
# 3    Phaeostachys spinifera (Johnston, 1847)  Animalia       Bryozoa
# 4      Haplopoma graniferum (Johnston, 1847)  Animalia       Bryozoa
#
#              class            order           family         genus  \
# 0      Eurotatoria           Ploima     Brachionidae     Keratella
# 1  Phylactolaemata     Plumatellida  Pectinatellidae  Pectinatella
# 2    Magnoliopsida          Rosales         Rosaceae  Scandosorbus
# 3     Gymnolaemata  Cheilostomatida     Escharinidae  Phaeostachys
# 4     Gymnolaemata  Cheilostomatida     Haplopomidae     Haplopoma
#
#   specificEpithet  ... scientificNameAuthorship  \
# 0         tropica  ...          (Apstein, 1907)
# 1       magnifica  ...            (Leidy, 1851)
# 2      intermedia  ...         (Ehrh.) Sennikov
# 3       spinifera  ...         (Johnston, 1847)
# 4      graniferum  ...         (Johnston, 1847)
#
#                                         taxonRemarks language  \
# 0  Sources considered for this taxon: https://doi...       en
# 1  Sources considered for this taxon: https://doi...       en
# 2  Sources considered for this taxon: https://doi...       en
# 3  Sources considered for this taxon: https://doi...       en
# 4  Sources considered for this taxon: https://doi...       en
#
#                                              license rightsHolder  \
# 0  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 1  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 2  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 3  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 4  http://creativecommons.org/licenses/by/4.0/leg...          NaN
#
#                                bibliographicCitation  \
# 0  https://www.gbif.org/species/1002621: Keratell...
# 1  https://www.gbif.org/species/1003567: Pectinat...
# 2  https://www.gbif.org/species/10071055: Scandos...
# 3  https://www.gbif.org/species/1007534: Phaeosta...
# 4  https://www.gbif.org/species/1008610: Haplopom...
#
#                               references institutionCode  \
# 0   https://www.gbif.org/species/1002621            ISSG
# 1   https://www.gbif.org/species/1003567            ISSG
# 2  https://www.gbif.org/species/10071055            ISSG
# 3   https://www.gbif.org/species/1007534            ISSG
# 4   https://www.gbif.org/species/1008610            ISSG
#
#                          datasetID  \
# 0  https://doi.org/10.15468/xoidmd
# 1  https://doi.org/10.15468/xoidmd
# 2  https://doi.org/10.15468/xoidmd
# 3  https://doi.org/10.15468/xoidmd
# 4  https://doi.org/10.15468/xoidmd
#
#                                          datasetName
# 0  Global Register of Introduced and Invasive Spe...
# 1  Global Register of Introduced and Invasive Spe...
# 2  Global Register of Introduced and Invasive Spe...
# 3  Global Register of Introduced and Invasive Spe...
# 4  Global Register of Introduced and Invasive Spe...
#
# [5 rows x 22 columns]

# %%
# %timeit usageKey = [int(key.split("/")[-1]) for key in df["id"]]
# Out:
# 1.17 ms ± 4.11 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit usageKey = list(map(lambda x: int(x.split("/")[-1]), df["id"]))
# Out:
# 1.31 ms ± 6.29 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
usageKey = [int(key.split("/")[-1]) for key in df["id"]]
df["usageKey"] = usageKey
df
# Out:
#                                          id  \
# 0      https://www.gbif.org/species/1002621
# 1      https://www.gbif.org/species/1003567
# 2     https://www.gbif.org/species/10071055
# 3      https://www.gbif.org/species/1007534
# 4      https://www.gbif.org/species/1008610
# ...                                     ...
# 3894   https://www.gbif.org/species/9791464
# 3895   https://www.gbif.org/species/9803191
# 3896   https://www.gbif.org/species/9817629
# 3897   https://www.gbif.org/species/9823072
# 3898   https://www.gbif.org/species/9890104
#
#                                     taxonID  \
# 0      https://www.gbif.org/species/1002621
# 1      https://www.gbif.org/species/1003567
# 2     https://www.gbif.org/species/10071055
# 3      https://www.gbif.org/species/1007534
# 4      https://www.gbif.org/species/1008610
# ...                                     ...
# 3894   https://www.gbif.org/species/9791464
# 3895   https://www.gbif.org/species/9803191
# 3896   https://www.gbif.org/species/9817629
# 3897   https://www.gbif.org/species/9823072
# 3898   https://www.gbif.org/species/9890104
#
#                                  scientificName   kingdom        phylum  \
# 0             Keratella tropica (Apstein, 1907)  Animalia      Rotifera
# 1          Pectinatella magnifica (Leidy, 1851)  Animalia       Bryozoa
# 2     Scandosorbus ×intermedia (Ehrh.) Sennikov   Plantae  Tracheophyta
# 3       Phaeostachys spinifera (Johnston, 1847)  Animalia       Bryozoa
# 4         Haplopoma graniferum (Johnston, 1847)  Animalia       Bryozoa
# ...                                         ...       ...           ...
# 3894       Colinus virginianus (Linnaeus, 1758)  Animalia      Chordata
# 3895      Pelusios castaneus (Schweigger, 1812)  Animalia      Chordata
# 3896    Lysichiton americanus × camtschatcensis   Plantae  Tracheophyta
# 3897                          Oxalis stricta L.   Plantae  Tracheophyta
# 3898        Xeroplexa intersecta (Poiret, 1801)  Animalia      Mollusca
#
#                 class            order           family         genus  \
# 0         Eurotatoria           Ploima     Brachionidae     Keratella
# 1     Phylactolaemata     Plumatellida  Pectinatellidae  Pectinatella
# 2       Magnoliopsida          Rosales         Rosaceae  Scandosorbus
# 3        Gymnolaemata  Cheilostomatida     Escharinidae  Phaeostachys
# 4        Gymnolaemata  Cheilostomatida     Haplopomidae     Haplopoma
# ...               ...              ...              ...           ...
# 3894             Aves      Galliformes   Odontophoridae       Colinus
# 3895       Testudines                     Pelomedusidae      Pelusios
# 3896       Liliopsida      Alismatales          Araceae    Lysichiton
# 3897    Magnoliopsida       Oxalidales      Oxalidaceae        Oxalis
# 3898       Gastropoda  Stylommatophora      Geomitridae     Xeroplexa
#
#      specificEpithet  ...                                       taxonRemarks  \
# 0            tropica  ...  Sources considered for this taxon: https://doi...
# 1          magnifica  ...  Sources considered for this taxon: https://doi...
# 2         intermedia  ...  Sources considered for this taxon: https://doi...
# 3          spinifera  ...  Sources considered for this taxon: https://doi...
# 4         graniferum  ...  Sources considered for this taxon: https://doi...
# ...              ...  ...                                                ...
# 3894     virginianus  ...  Sources considered for this taxon: https://doi...
# 3895       castaneus  ...  Sources considered for this taxon: https://doi...
# 3896                  ...  Sources considered for this taxon: https://doi...
# 3897         stricta  ...  Sources considered for this taxon: https://doi...
# 3898      intersecta  ...  Sources considered for this taxon: https://doi...
#
#      language                                            license rightsHolder  \
# 0          en  http://creativecommons.org/licenses/by/4.0/leg...
# 1          en  http://creativecommons.org/licenses/by/4.0/leg...
# 2          en  http://creativecommons.org/licenses/by/4.0/leg...
# 3          en  http://creativecommons.org/licenses/by/4.0/leg...
# 4          en  http://creativecommons.org/licenses/by/4.0/leg...
# ...       ...                                                ...          ...
# 3894       en  http://creativecommons.org/licenses/by/4.0/leg...
# 3895       en  http://creativecommons.org/licenses/by/4.0/leg...
# 3896       en  http://creativecommons.org/licenses/by/4.0/leg...
# 3897       en  http://creativecommons.org/licenses/by/4.0/leg...
# 3898       en  http://creativecommons.org/licenses/by/4.0/leg...
#
#                                   bibliographicCitation  \
# 0     https://www.gbif.org/species/1002621: Keratell...
# 1     https://www.gbif.org/species/1003567: Pectinat...
# 2     https://www.gbif.org/species/10071055: Scandos...
# 3     https://www.gbif.org/species/1007534: Phaeosta...
# 4     https://www.gbif.org/species/1008610: Haplopom...
# ...                                                 ...
# 3894  https://www.gbif.org/species/9791464: Colinus ...
# 3895  https://www.gbif.org/species/9803191: Pelusios...
# 3896  https://www.gbif.org/species/9817629: Lysichit...
# 3897  https://www.gbif.org/species/9823072: Oxalis s...
# 3898  https://www.gbif.org/species/9890104: Xeroplex...
#
#                                  references institutionCode  \
# 0      https://www.gbif.org/species/1002621            ISSG
# 1      https://www.gbif.org/species/1003567            ISSG
# 2     https://www.gbif.org/species/10071055            ISSG
# 3      https://www.gbif.org/species/1007534            ISSG
# 4      https://www.gbif.org/species/1008610            ISSG
# ...                                     ...             ...
# 3894   https://www.gbif.org/species/9791464            ISSG
# 3895   https://www.gbif.org/species/9803191            ISSG
# 3896   https://www.gbif.org/species/9817629            ISSG
# 3897   https://www.gbif.org/species/9823072            ISSG
# 3898   https://www.gbif.org/species/9890104            ISSG
#
#                             datasetID  \
# 0     https://doi.org/10.15468/xoidmd
# 1     https://doi.org/10.15468/xoidmd
# 2     https://doi.org/10.15468/xoidmd
# 3     https://doi.org/10.15468/xoidmd
# 4     https://doi.org/10.15468/xoidmd
# ...                               ...
# 3894  https://doi.org/10.15468/xoidmd
# 3895  https://doi.org/10.15468/xoidmd
# 3896  https://doi.org/10.15468/xoidmd
# 3897  https://doi.org/10.15468/xoidmd
# 3898  https://doi.org/10.15468/xoidmd
#
#                                              datasetNam  usageKey
# 0     Global Register of Introduced and Invasive Spe...   1002621
# 1     Global Register of Introduced and Invasive Spe...   1003567
# 2     Global Register of Introduced and Invasive Spe...  10071055
# 3     Global Register of Introduced and Invasive Spe...   1007534
# 4     Global Register of Introduced and Invasive Spe...   1008610
# ...                                                 ...       ...
# 3894  Global Register of Introduced and Invasive Spe...   9791464
# 3895  Global Register of Introduced and Invasive Spe...   9803191
# 3896  Global Register of Introduced and Invasive Spe...   9817629
# 3897  Global Register of Introduced and Invasive Spe...   9823072
# 3898  Global Register of Introduced and Invasive Spe...   9890104
#
# [3899 rows x 23 columns]

# %%
def fetchTaxonInfoDWC(inpFile, outFile, inpPath="", outPath=""):
    #Read in the DwC file immediately as a DF with a tab separator and utf8 encoding
    dwcDF = pd.read_csv(os.path.join(inpPath, inpFile), sep="\t", encoding="utf8")
    #Extract the usageKey from the taxonID field in the dataframe
    usageKeys = [key.split("/")[-1] for key in df["taxonID"]]
    with open(os.path.join(outPath, outFile), "w") as f:
        #Condense usageKeys to a single str 
        usageKeyStr = ",".join(usageKeys)
        #write to the file where the speciesKeys will be stored
        f.write(usageKeyStr)
        f.close()

# %%
df = fetchTaxonInfoDWC("taxon.txt", "test.csv", inpPath="dwca-unified-checklist-v1.14/")
df.head()
# Out:
#                                       id  \
# 0   https://www.gbif.org/species/1002621
# 1   https://www.gbif.org/species/1003567
# 2  https://www.gbif.org/species/10071055
# 3   https://www.gbif.org/species/1007534
# 4   https://www.gbif.org/species/1008610
#
#                                  taxonID  \
# 0   https://www.gbif.org/species/1002621
# 1   https://www.gbif.org/species/1003567
# 2  https://www.gbif.org/species/10071055
# 3   https://www.gbif.org/species/1007534
# 4   https://www.gbif.org/species/1008610
#
#                               scientificName   kingdom        phylum  \
# 0          Keratella tropica (Apstein, 1907)  Animalia      Rotifera
# 1       Pectinatella magnifica (Leidy, 1851)  Animalia       Bryozoa
# 2  Scandosorbus ×intermedia (Ehrh.) Sennikov   Plantae  Tracheophyta
# 3    Phaeostachys spinifera (Johnston, 1847)  Animalia       Bryozoa
# 4      Haplopoma graniferum (Johnston, 1847)  Animalia       Bryozoa
#
#              class            order           family         genus  \
# 0      Eurotatoria           Ploima     Brachionidae     Keratella
# 1  Phylactolaemata     Plumatellida  Pectinatellidae  Pectinatella
# 2    Magnoliopsida          Rosales         Rosaceae  Scandosorbus
# 3     Gymnolaemata  Cheilostomatida     Escharinidae  Phaeostachys
# 4     Gymnolaemata  Cheilostomatida     Haplopomidae     Haplopoma
#
#   specificEpithet  ...                                       taxonRemarks  \
# 0         tropica  ...  Sources considered for this taxon: https://doi...
# 1       magnifica  ...  Sources considered for this taxon: https://doi...
# 2      intermedia  ...  Sources considered for this taxon: https://doi...
# 3       spinifera  ...  Sources considered for this taxon: https://doi...
# 4      graniferum  ...  Sources considered for this taxon: https://doi...
#
#   language                                            license rightsHolder  \
# 0       en  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 1       en  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 2       en  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 3       en  http://creativecommons.org/licenses/by/4.0/leg...          NaN
# 4       en  http://creativecommons.org/licenses/by/4.0/leg...          NaN
#
#                                bibliographicCitation  \
# 0  https://www.gbif.org/species/1002621: Keratell...
# 1  https://www.gbif.org/species/1003567: Pectinat...
# 2  https://www.gbif.org/species/10071055: Scandos...
# 3  https://www.gbif.org/species/1007534: Phaeosta...
# 4  https://www.gbif.org/species/1008610: Haplopom...
#
#                               references  institutionCode  \
# 0   https://www.gbif.org/species/1002621             ISSG
# 1   https://www.gbif.org/species/1003567             ISSG
# 2  https://www.gbif.org/species/10071055             ISSG
# 3   https://www.gbif.org/species/1007534             ISSG
# 4   https://www.gbif.org/species/1008610             ISSG
#
#                          datasetID  \
# 0  https://doi.org/10.15468/xoidmd
# 1  https://doi.org/10.15468/xoidmd
# 2  https://doi.org/10.15468/xoidmd
# 3  https://doi.org/10.15468/xoidmd
# 4  https://doi.org/10.15468/xoidmd
#
#                                          datasetName  usageKey
# 0  Global Register of Introduced and Invasive Spe...   1002621
# 1  Global Register of Introduced and Invasive Spe...   1003567
# 2  Global Register of Introduced and Invasive Spe...  10071055
# 3  Global Register of Introduced and Invasive Spe...   1007534
# 4  Global Register of Introduced and Invasive Spe...   1008610
#
# [5 rows x 23 columns]

# %%
fetchTaxonInfoDWC("taxon.txt", "test.csv", inpPath="dwca-unified-checklist-v1.14/")
# Out:
# 1002621,1003567,10071055,1007534,1008610,1008612,1008955,1010644,10108775,1013526,1014565,1016841,1017419,10269496,1031394,1031400,1031512,1031520,1031524,1031564,1031677,1031680,1031684,1031685,1031737,1031742,1031743,1032262,1032377,10329298,10411852,1043717,1043978,1045323,1047536,10545407,10578411,10629881,10646747,10676000,10701161,10730110,10755213,10773250,10786206,10797854,10800064,10801424,10852031,10857535,10902460,10920460,10933479,10937982,10944522,10948891,10953644,1095946,10966302,10972541,10986555,11007246,11055820,11064584,11104870,11107889,1111797,11136683,11141765,11162940,1119292,11205618,11335341,1133603,1152186,11528335,11794300,11844792,11921804,1194885,1194989,1195013,12132283,12187916,12205713,12218002,12246414,12254070,12262171,1247584,1276876,1309600,1309606,1309635,1309652,1311477,1313740,1314773,1316805,1316908,1319260,1320777,1321805,1322674,1323402,1325561,1326634,1342324,1346919,1349836,1371011,1411953,1419894,1420197,1420612,1420765,1420769,1420791,1420795,1420828,1420829,1420846,1420857,1421091,1421095,1421105,1422818,1423286,1450317,1521740,1523628,1548900,1551754,1577153,1579447,1622599,1622658,1623077,1623354,1626096,1650106,1651430,1652150,1652212,1683815,1690276,1690429,1702101,1707320,1713034,1714140,1718308,1719204,1720196,1722140,1722299,1728965,1737131,1749449,1749580,1751299,1795068,1829659,1830284,1830823,1835422,1852787,1852831,1865660,1866356,1873051,1873890,1873903,1885213,1886729,1891245,1910629,1932752,1941864,1971998,1995489,1995681,1997215,1998083,1998599,2000152,2000204,2007665,2008616,2010226,2012132,2020655,2020686,2020688,2020779,2020832,2020879,2029273,2029899,2037925,2037991,2038171,2041682,2047706,2049296,2049512,2049661,2049722,2049732,2053954,2064632,2077985,2078852,2080592,2088481,2091932,2092040,2095283,2110811,2114326,2114446,2114769,2115706,2115724,2115769,2128482,2128502,2138649,2138688,2140406,2141241,2141622,2142456,2145078,2148040,2149679,2149761,2149847,2149992,2150043,2150089,2152793,2152822,2153287,2153712,2153759,2153791,2155557,2155807,2155867,2157203,2157245,2157278,2157335,2157928,2157942,2157944,2157949,2157984,2158821,2161467,2161710,2161911,2162049,2162464,2162525,2162537,2164194,2164198,2169430,2171214,2172103,2172282,2172885,2173887,2174528,2176168,2176858,2177741,2188249,2202641,2202786,2203165,2204831,2204981,2205951,2206086,2209044,2211487,2211599,2215949,2217982,2219149,2219863,2220312,2220347,2220417,2223840,2224970,2225646,2225770,2225772,2225776,2226990,2227289,2227300,2227663,2228667,2234836,2242011,2266009,2266561,2266754,2284443,2285504,2286079,2286388,2287072,2287073,2287076,2287249,2287615,2287668,2288847,2288859,2288926,2294131,2294275,2294277,2294284,2295309,2295425,2295442,2296805,2296807,2297108,2307447,2307726,2307929,2308541,2308549,2308574,2308605,2308609,2320810,2320998,2321001,2321010,2321012,2327735,2330928,2331498,2331942,2337607,2340977,2340989,2350050,2351064,2351136,2351211,2351271,2351413,2360504,2362030,2362473,2362486,2362868,2362881,2366634,2367033,2367742,2367913,2367919,2374521,2379089,2379105,2379245,2382155,2394486,2394563,2399874,2402129,2402168,2423441,2426640,2426658,2426661,2427091,2427555,2431781,2431875,2431886,2431965,2431993,2432063,2432352,2433536,2434126,2434552,2435035,2435451,2436886,2436940,2437232,2437282,2437394,2437397,2437399,2437450,2437619,2439261,2439270,2439838,2440196,2440946,2440954,2441122,2441454,2441461,2441533,2441658,2441905,2442664,2442665,2442843,2443002,2443074,2443079,2443133,2443173,2443339,2443597,2443876,2444141,2444221,2444339,2444356,2445034,2445496,2447367,2447418,2449133,2453826,2453882,2454645,2455615,2455676,2457224,2457378,2457522,2457577,2457825,2458374,2458386,2458438,2458538,2458916,2459603,2459658,2459675,2464899,2465003,2465369,2465380,2465402,2465626,2465641,2465649,2466496,2469188,2470376,2470656,2473221,2473341,2473421,2473477,2474029,2474045,2474051,2474055,2474162,2474416,2474936,2474937,2474942,2474944,2475212,2475235,2475364,2475373,2475648,2475679,2476041,24790 ...

# %% [markdown]
# # Create SQL script
