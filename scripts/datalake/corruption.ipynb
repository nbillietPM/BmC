# %%
# Copy the path to one of your massive "corrupt" files
file_path = "microlake/raw/wekeo/EO_EEA_DAT_HRL_TCF/Dominant_Leaf_Type/DLT_2012_020m_E40N20_03035_d03.zip"
with open(file_path, "rb") as f:
    header = f.read(4)
    print(f"Magic Bytes: {header}")
# Out:
# Magic Bytes: b'PK\x03\x04'
